# %%
from runTregex import Treebank

pattern = "/.*/ >: (/VBN/ $++ (PP < (IN < by)))"
dir = "/Users/ibersue/Documents/Computational Methods /144coursework/Homeworks/Homework 6/treebank_3/parsed/mrg/wsj/"

c = Treebank(dir,pattern)
c.run()
# Out:
# Running tregex...
# Processing output...
# Done!

# %%
len(c)
# Out:
# 2932

# %%
def createDict(x):
    freqDict = {} 
    for tree in x.trees: 
        word = tree.matchTree
        if word not in freqDict:             
            freqDict[word] = 1
        else:
            freqDict[word] += 1
    return freqDict

# %%
sorted(createDict(c).items(), key=lambda item: item[1], reverse=True)
# Out:
# [(u'led', 86),
#  (u'made', 71),
#  (u'owned', 70),
#  (u'backed', 53),
#  (u'hurt', 51),
#  (u'caused', 49),
#  (u'controlled', 44),
#  (u'offset', 43),
#  (u'sold', 40),
#  (u'used', 39),
#  (u'followed', 38),
#  (u'approved', 38),
#  (u'held', 36),
#  (u'offered', 35),
#  (u'paid', 30),
#  (u'produced', 29),
#  (u'headed', 28),
#  (u'created', 27),
#  (u'acquired', 27),
#  (u'affected', 26),
#  (u'issued', 24),
#  (u'taken', 24),
#  (u'rated', 22),
#  (u'filed', 22),
#  (u'developed', 21),
#  (u'covered', 21),
#  (u'compiled', 20),
#  (u'helped', 20),
#  (u'priced', 19),
#  (u'reported', 18),
#  (u'supported', 18),
#  (u'set', 17),
#  (u'boosted', 16),
#  (u'calculated', 16),
#  (u'provided', 16),
#  (u'run', 16),
#  (u'sought', 15),
#  (u'succeeded', 15),
#  (u'conducted', 15),
#  (u'hit', 15),
#  (u'passed', 14),
#  (u'triggered', 14),
#  (u'placed', 14),
#  (u'fueled', 12),
#  (u'accompanied', 12),
#  (u'encouraged', 12),
#  (u'driven', 12),
#  (u'aided', 11),
#  (u'brought', 11),
#  (u'bolstered', 11),
#  (u'determined', 11),
#  (u'measured', 11),
#  (u'employed', 11),
#  (u'dominated', 10),
#  (u'approached', 10),
#  (u'buoyed', 10),
#  (u'considered', 10),
#  (u'raised', 10),
#  (u'managed', 9),
#  (u'represented', 9),
#  (u'designed', 9),
#  (u'financed', 9),
#  (u'proposed', 9),
#  (u'sponsored', 9),
#  (u'required', 9),
#  (u'handled', 8),
#  (u'appointed', 8),
#  (u'pushed', 8),
#  (u'influenced', 8),
#  (u'hampered', 8),
#  (u'built', 8),
#  (u'guaranteed', 8),
#  (u'Guaranteed', 8),
#  (u'tracked', 8),
#  (u'signed', 8),
#  (u'prepared', 8),
#  (u'funded', 7),
#  (u'published', 7),
#  (u'cited', 7),
#  (u'battered', 7),
#  (u'purchased', 7),
#  (u'secured', 7),
#  (u'prompted', 7),
#  (u'surrounded', 7),
#  (u'announced', 7),
#  (u'sparked', 7),
#  (u'done', 7),
#  (u'given', 7),
#  (u'adopted', 7),
#  (u'rejected', 7),
#  (u'released', 7),
#  (u'underwritten', 7),
#  (u'turned', 7),
#  (u'spurred', 7),
#  (u'supplied', 6),
#  (u'opposed', 6),
#  (u'viewed', 6),
#  (u'surveyed', 6),
#  (u'written', 6),
#  (u'won', 6),
#  (u'bought', 6),
#  (u'described', 6),
#  (u'formed', 6),
#  (u'replaced', 6),
#  (u'launched', 6),
#  (u'played', 6),
#  (u'protected', 6),
#  (u'introduced', 6),
#  (u'ordered', 6),
#  (u'founded', 5),
#  (u'advised', 5),
#  (u'shared', 5),
#  (u'hammered', 5),
#  (u'initiated', 5),
#  (u'mandated', 5),
#  (u'put', 5),
#  (u'hired', 5),
#  (u'received', 5),
#  (u'owed', 5),
#  (u'magnified', 5),
#  (u'surprised', 5),
#  (u'accepted', 5),
#  (u'imposed', 5),
#  (u'reduced', 5),
#  (u'shaken', 5),
#  (u'carried', 5),
#  (u'vacated', 5),
#  (u'insured', 5),
#  (u'called', 5),
#  (u'limited', 4),
#  (u'presented', 4),
#  (u'established', 4),
#  (u'assisted', 4),
#  (u'told', 4),
#  (u'drafted', 4),
#  (u'inspired', 4),
#  (u'commissioned', 4),
#  (u'troubled', 4),
#  (u'shown', 4),
#  (u'restricted', 4),
#  (u'found', 4),
#  (u'complicated', 4),
#  (u'forced', 4),
#  (u'agreed', 4),
#  (u'quoted', 4),
#  (u'distributed', 4),
#  (u'sued', 4),
#  (u'criticized', 4),
#  (u'enhanced', 4),
#  (u'pressured', 4),
#  (u'cut', 4),
#  (u'faced', 4),
#  (u'attacked', 4),
#  (u'painted', 4),
#  (u'squeezed', 4),
#  (u'claimed', 4),
#  (u'reviewed', 4),
#  (u'rocked', 4),
#  (u'evidenced', 4),
#  (u'struck', 4),
#  (u'matched', 4),
#  (u'devised', 4),
#  (u'posed', 4),
#  (u'endorsed', 4),
#  (u'prohibited', 4),
#  (u'assumed', 4),
#  (u'challenged', 4),
#  (u'besieged', 4),
#  (u'sustained', 4),
#  (u'entered', 4),
#  (u'directed', 4),
#  (u'generated', 4),
#  (u'governed', 4),
#  (u'disapproved', 3),
#  (u'sent', 3),
#  (u'seized', 3),
#  (u'joined', 3),
#  (u'buffeted', 3),
#  (u'marketed', 3),
#  (u'sung', 3),
#  (u'filled', 3),
#  (u'deemed', 3),
#  (u'Founded', 3),
#  (u'named', 3),
#  (u'suffered', 3),
#  (u'subsidized', 3),
#  (u'valued', 3),
#  (u'organized', 3),
#  (u'welcomed', 3),
#  (u'committed', 3),
#  (u'negotiated', 3),
#  (u'Stung', 3),
#  (u'undermined', 3),
#  (u'notified', 3),
#  (u'underpinned', 3),
#  (u'attended', 3),
#  (u'favored', 3),
#  (u'Rated', 3),
#  (u'embraced', 3),
#  (u'reached', 3),
#  (u'awarded', 3),
#  (u'vetoed', 3),
#  (u'submitted', 3),
#  (u'thwarted', 3),
#  (u'recommended', 3),
#  (u'absorbed', 3),
#  (u'exercised', 3),
#  (u'cleared', 3),
#  (u'singled', 3),
#  (u'dragged', 3),
#  (u'discovered', 3),
#  (u'plagued', 3),
#  (u'operated', 3),
#  (u'frustrated', 3),
#  (u'regulated', 3),
#  (u'informed', 3),
#  (u'suggested', 3),
#  (u'selected', 3),
#  (u'spooked', 3),
#  (u'injured', 3),
#  (u'distracted', 3),
#  (u'charged', 3),
#  (u'polled', 3),
#  (u'increased', 3),
#  (u'disappointed', 3),
#  (u'Led', 3),
#  (u'recorded', 3),
#  (u'murdered', 3),
#  (u'cheered', 3),
#  (u'permitted', 3),
#  (u'rebuffed', 3),
#  (u'donated', 3),
#  (u'impressed', 3),
#  (u'redeemed', 3),
#  (u'topped', 3),
#  (u'incurred', 3),
#  (u'dogged', 2),
#  (u'saved', 2),
#  (u'assembled', 2),
#  (u'praised', 2),
#  (u'puzzled', 2),
#  (u'solved', 2),
#  (u'slowed', 2),
#  (u'crippled', 2),
#  (u'explained', 2),
#  (u'dictated', 2),
#  (u'depicted', 2),
#  (u'Aided', 2),
#  (u'dropped', 2),
#  (u'guarded', 2),
#  (u'whipsawed', 2),
#  (u'swayed', 2),
#  (u'damaged', 2),
#  (u'interrupted', 2),
#  (u'deserted', 2),
#  (u'acquitted', 2),
#  (u'syndicated', 2),
#  (u'Encouraged', 2),
#  (u'interpreted', 2),
#  (u'dismissed', 2),
#  (u'mentioned', 2),
#  (u'disclosed', 2),
#  (u'stalled', 2),
#  (u'investigated', 2),
#  (u'anticipated', 2),
#  (u'disrupted', 2),
#  (u'repassed', 2),
#  (u'enacted', 2),
#  (u'aggravated', 2),
#  (u'shut', 2),
#  (u'disputed', 2),
#  (u'solicited', 2),
#  (u'dubbed', 2),
#  (u'disturbed', 2),
#  (u'caught', 2),
#  (u'courted', 2),
#  (u'achieved', 2),
#  (u'relieved', 2),
#  (u'earmarked', 2),
#  (u'interviewed', 2),
#  (u'decided', 2),
#  (u'sentenced', 2),
#  (u'depleted', 2),
#  (u'distorted', 2),
#  (u'voiced', 2),
#  (u'seen', 2),
#  (u'linked', 2),
#  (u'collateralized', 2),
#  (u'pursued', 2),
#  (u'consumed', 2),
#  (u'upset', 2),
#  (u'stalked', 2),
#  (u'beaten', 2),
#  (u'contacted', 2),
#  (u'nominated', 2),
#  (u'expressed', 2),
#  (u'enjoyed', 2),
#  (u'earned', 2),
#  (u'compounded', 2),
#  (u'banned', 2),
#  (u'hailed', 2),
#  (u'interrogated', 2),
#  (u'processed', 2),
#  (u'hobbled', 2),
#  (u'ignored', 2),
#  (u'declared', 2),
#  (u'elected', 2),
#  (u'accused', 2),
#  (u'aroused', 2),
#  (u'tainted', 2),
#  (u'blocked', 2),
#  (u'targeted', 2),
#  (u'spared', 2),
#  (u'Spurred', 2),
#  (u'asked', 2),
#  (u'maintained', 2),
#  (u'crafted', 2),
#  (u'ravaged', 2),
#  (u'powered', 2),
#  (u'muddied', 2),
#  (u'expected', 2),
#  (u'copied', 2),
#  (u'worked', 2),
#  (u'abandoned', 2),
#  (u'guided', 2),
#  (u'foreshadowed', 2),
#  (u'pressed', 2),
#  (u'motivated', 2),
#  (u'confirmed', 2),
#  (u'highlighted', 2),
#  (u'stimulated', 2),
#  (u'angered', 2),
#  (u'greeted', 2),
#  (u'discouraged', 2),
#  (u'blamed', 2),
#  (u'overshadowed', 2),
#  (u'Compiled', 2),
#  (u'undertaken', 2),
#  (u'handed', 2),
#  (u'captured', 2),
#  (u'monitored', 2),
#  (u'resolved', 2),
#  (u'chaired', 2),
#  (u'read', 2),
#  (u'stung', 2),
#  (u'propelled', 2),
#  (u'ruled', 2),
#  (u'eroded', 2),
#  (u'displaced', 2),
#  (u'lost', 2),
#  (u'envisioned', 2),
#  (u'dulled', 2),
#  (u'served', 2),
#  (u'tempered', 2),
#  (u'masked', 2),
#  (u'denied', 2),
#  (u'broken', 2),
#  (u'snapped', 2),
#  (u'discussed', 2),
#  (u'persuaded', 2),
#  (u'capped', 2),
#  (u'fired', 2),
#  (u'raped', 2),
#  (u'authorized', 2),
#  (u'stymied', 2),
#  (u'unsettled', 2),
#  (u'delayed', 2),
#  (u'designated', 2),
#  (u'lowered', 2),
#  (u'arranged', 2),
#  (u'attached', 2),
#  (u'burdened', 2),
#  (u'defined', 2),
#  (u'estimated', 2),
#  (u'requested', 2),
#  (u'perpetrated', 1),
#  (u'primed', 1),
#  (u'amplified', 1),
#  (u'co-sponsored', 1),
#  (u'syndciated', 1),
#  (u'dissatisfied', 1),
#  (u'preserved', 1),
#  (u'hamstrung', 1),
#  (u'jinxed', 1),
#  (u'bombarded', 1),
#  (u'engineered', 1),
#  (u'Barred', 1),
#  (u'Pressed', 1),
#  (u'forked', 1),
#  (u'stabbed', 1),
#  (u'defended', 1),
#  (u'continued', 1),
#  (u'gobbled', 1),
#  (u'illustrated', 1),
#  (u'perceived', 1),
#  (u'contemplated', 1),
#  (u'harried', 1),
#  (u'Headed', 1),
#  (u'damped', 1),
#  (u'undone', 1),
#  (u'concluded', 1),
#  (u'Filmed', 1),
#  (u'infringed', 1),
#  (u'hindered', 1),
#  (u'licensed', 1),
#  (u'knitted', 1),
#  (u'necessitated', 1),
#  (u'enclosed', 1),
#  (u'picked', 1),
#  (u'replicated', 1),
#  (u'nationalized', 1),
#  (u'contributed', 1),
#  (u'disbursed', 1),
#  (u'learned', 1),
#  (u'dispatched', 1),
#  (u'Created', 1),
#  (u'jolted', 1),
#  (u'dissipated', 1),
#  (u'invented', 1),
#  (u'obtained', 1),
#  (u'colored', 1),
#  (u'impacted', 1),
#  (u'changed', 1),
#  (u'Bolstered', 1),
#  (u'taped', 1),
#  (u'accomplished', 1),
#  (u'Distributed', 1),
#  (u'addressed', 1),
#  (u'drowned', 1),
#  (u'spawned', 1),
#  (u'bribed', 1),
#  (u'strapped', 1),
#  (u'fed', 1),
#  (u'heartened', 1),
#  (u'wiped', 1),
#  (u'upheld', 1),
#  (u'heralded', 1),
#  (u'voted', 1),
#  (u'assailed', 1),
#  (u'neglected', 1),
#  (u'Inspired', 1),
#  (u'clobbered', 1),
#  (u'tested', 1),
#  (u'reignited', 1),
#  (u'inhabited', 1),
#  (u'respected', 1),
#  (u'heard', 1),
#  (u'entertained', 1),
#  (u'knocked', 1),
#  (u'Bitten', 1),
#  (u'indicated', 1),
#  (u'concocted', 1),
#  (u'confused', 1),
#  (u'voided', 1),
#  (u'escaped', 1),
#  (u'Written', 1),
#  (u'allowed', 1),
#  (u'pieced', 1),
#  (u'repackaged', 1),
#  (u'wielded', 1),
#  (u'reoriented', 1),
#  (u'shipped', 1),
#  (u'ratified', 1),
#  (u'foreseen', 1),
#  (u'bothered', 1),
#  (u'whacked', 1),
#  (u'leased', 1),
#  (u'coined', 1),
#  (u'dwarfed', 1),
#  (u'disgusted', 1),
#  (u'revealed', 1),
#  (u'decimated', 1),
#  (u'pulled', 1),
#  (u'divided', 1),
#  (u'executed', 1),
#  (u'exploited', 1),
#  (u'sanctioned', 1),
#  (u'displayed', 1),
#  (u'wronged', 1),
#  (u'rewarded', 1),
#  (u'contaminated', 1),
#  (u'Hit', 1),
#  (u'countered', 1),
#  (u'termed', 1),
#  (u'chosen', 1),
#  (u'blackened', 1),
#  (u'destroyed', 1),
#  (u'entranced', 1),
#  (u'hidden', 1),
#  (u'undercut', 1),
#  (u'pre-signed', 1),
#  (u'rattled', 1),
#  (u'documented', 1),
#  (u'touched', 1),
#  (u'reassured', 1),
#  (u'arrested', 1),
#  (u'identified', 1),
#  (u'stopped', 1),
#  (u'leveled', 1),
#  (u'characterized', 1),
#  (u'afforded', 1),
#  (u'preceded', 1),
#  (u'exacerbated', 1),
#  (u'tilted', 1),
#  (u'populated', 1),
#  (u'begun', 1),
#  (u'exceeded', 1),
#  (u'skewed', 1),
#  (u'borne', 1),
#  (u'opened', 1),
#  (u'insisted', 1),
#  (u'attracted', 1),
#  (u'researched', 1),
#  (u'monopolized', 1),
#  (u'assured', 1),
#  (u'threatened', 1),
#  (u'electrified', 1),
#  (u'Used', 1),
#  (u'certified', 1),
#  (u'molded', 1),
#  (u'thrown', 1),
#  (u'cured', 1),
#  (u'Developed', 1),
#  (u'diminished', 1),
#  (u'Helped', 1),
#  (u'comforted', 1),
#  (u'traveled', 1),
#  (u'embarrassed', 1),
#  (u'pummeled', 1),
#  (u'implicated', 1),
#  (u'withheld', 1),
#  (u'lulled', 1),
#  (u'rewritten', 1),
#  (u'bloodied', 1),
#  (u'racked', 1),
#  (u'listed', 1),
#  (u'peddled', 1),
#  (u'rankled', 1),
#  (u'trapped', 1),
#  (u'reversed', 1),
#  (u'circulated', 1),
#  (u'broadcast', 1),
#  (u'contracted', 1),
#  (u'obstructed', 1),
#  (u'brushed', 1),
#  (u'hypnotized', 1),
#  (u'imperiled', 1),
#  (u'de-emphasized', 1),
#  (u'orchestrated', 1),
#  (u'visited', 1),
#  (u'ousted', 1),
#  (u'spent', 1),
#  (u'constrained', 1),
#  (u'shocked', 1),
#  (u'gunned', 1),
#  (u'completed', 1),
#  (u'added', 1),
#  (u'Emboldened', 1),
#  (u'thrilled', 1),
#  (u'blackmailed', 1),
#  (u'eaten', 1),
#  (u'cushioned', 1),
#  (u'looked', 1),
#  (u'ignited', 1),
#  (u'left', 1),
#  (u'overwhelmed', 1),
#  (u'disbanded', 1),
#  (u'heckled', 1),
#  (u'remunerated', 1),
#  (u'pre-approved', 1),
#  (u'unleashed', 1),
#  (u'lauded', 1),
#  (u'implemented', 1),
#  (u'dreamed', 1),
#  (u'pegged', 1),
#  (u'posted', 1),
#  (u'nullified', 1),
#  (u'borrowed', 1),
#  (u'harmed', 1),
#  (u'Funded', 1),
#  (u'preferred', 1),
#  (u'haunted', 1),
#  (u'negated', 1),
#  (u'humbled', 1),
#  (u'installed', 1),
#  (u'justified', 1),
#  (u'devoured', 1),
#  (u'wrested', 1),
#  (u'marred', 1),
#  (u'spotted', 1),
#  (u'bandied', 1),
#  (u'swept', 1),
#  (u'scolded', 1),
#  (u'anchored', 1),
#  (u'seated', 1),
#  (u'safeguarded', 1),
#  (u'hastened', 1),
#  (u'staffed', 1),
#  (u'invoked', 1),
#  (u'fascinated', 1),
#  (u'forecast', 1),
#  (u'originated', 1),
#  (u'closed', 1),
#  (u'bedeviled', 1),
#  (u'burned', 1),
#  (u'deposed', 1),
#  (u'ascribed', 1),
#  (u'tackled', 1),
#  (u'betrayed', 1),
#  (u'Prompted', 1),
#  (u'invited', 1),
#  (u'bludgeoned', 1),
#  (u'ranked', 1),
#  (u'pounded', 1),
#  (u'planned', 1),
#  (u'forgotten', 1),
#  (u'confronted', 1),
#  (u'Blocked', 1),
#  (u'Offered', 1),
#  (u'Surrounded', 1),
#  (u'withdrawn', 1),
#  (u'erased', 1),
#  (u'Prevented', 1),
#  (u'been', 1),
#  (u'convicted', 1),
#  (u'spread', 1),
#  (u'outweighed', 1),
#  (u'assassinated', 1),
#  (u'patrolled', 1),
#  (u'Downgraded', 1),
#  (u'Shaken', 1),
#  (u'nicked', 1),
#  (u'recalled', 1),
#  (u'proven', 1),
#  (u'coordinated', 1),
#  (u'resisted', 1),
#  (u'impoverished', 1),
#  (u'frozen', 1),
#  (u'expanded', 1),
#  (u'Trumped', 1),
#  (u'Pestered', 1),
#  (u'tarnished', 1),
#  (u'overlooked', 1),
#  (u'dumped', 1),
#  (u'tendered', 1),
#  (u'defeated', 1),
#  (u'dazzled', 1),
#  (u'examined', 1),
#  (u'punched', 1),
#  (u'sapped', 1),
#  (u'peopled', 1),
#  (u'relaunched', 1),
#  (u'tapped', 1),
#  (u'extended', 1),
#  (u'Imprisoned', 1),
#  (u'flooded', 1),
#  (u'squatted', 1),
#  (u'outperformed', 1),
#  (u'muffled', 1),
#  (u'flown', 1),
#  (u'symbolized', 1),
#  (u'prescribed', 1),
#  (u'appropriated', 1),
#  (u'discounted', 1),
#  (u'kicked', 1),
#  (u'echoed', 1),
#  (u'detained', 1),
#  (u'appalled', 1),
#  (u'coveted', 1),
#  (u'beset', 1),
#  (u'nicknamed', 1),
#  (u'afflicted', 1),
#  (u'ushered', 1),
#  (u'chided', 1),
#  (u'urged', 1),
#  (u'burnt', 1),
#  (u'regarded', 1),
#  (u'killed', 1),
#  (u'lured', 1),
#  (u'transformed', 1),
#  (u'Made', 1),
#  (u'quieted', 1),
#  (u'clouded', 1),
#  (u'crushed', 1),
#  (u'co-managed', 1),
#  (u'predetermined', 1),
#  (u'Flanked', 1),
#  (u'torpedoed', 1),
#  (u'boycotted', 1),
#  (u'advanced', 1),
#  (u'profferred', 1),
#  (u'restrained', 1),
#  (u'misled', 1),
#  (u'translated', 1),
#  (u'botched', 1),
#  (u'scared', 1),
#  (u'specified', 1),
#  (u'sheared', 1),
#  (u'perfected', 1),
#  (u'abetted', 1),
#  (u'subsumed', 1),
#  (u'summoned', 1),
#  (u'screwed', 1),
#  (u'tossed', 1),
#  (u'demonstrated', 1),
#  (u'pinched', 1),
#  (u'buttressed', 1),
#  (u'manufactured', 1),
#  (u'raided', 1),
#  (u'Signed', 1),
#  (u'torched', 1),
#  (u'strangled', 1),
#  (u'smothered', 1),
#  (u'derailed', 1),
#  (u'recognized', 1),
#  (u'supervised', 1),
#  (u'stoked', 1),
#  (u'second-guessed', 1),
#  (u'irked', 1),
#  (u'imitated', 1),
#  (u'rendered', 1),
#  (u'obliterated', 1),
#  (u'bound', 1),
#  (u'framed', 1),
#  (u'frightened', 1),
#  (u'despised', 1),
#  (u'fought', 1),
#  (u'recruited', 1),
#  (u'authored', 1),
#  (u'emulated', 1),
#  (u'co-anchored', 1),
#  (u'impeded', 1),
#  (u'pleased', 1),
#  (u'deployed', 1),
#  (u'evinced', 1),
#  (u'Buoyed', 1),
#  (u'detailed', 1),
#  (u'moved', 1),
#  (u'alarmed', 1),
#  (u'Attracted', 1),
#  (u'promised', 1),
#  (u'watched', 1),
#  (u'curtailed', 1),
#  (u'inflated', 1),
#  (u'weakened', 1),
#  (u'administered', 1),
#  (u'misinterpreted', 1),
#  (u'delivered', 1),
#  (u'jeopardized', 1),
#  (u'felt', 1),
#  (u'fertilized', 1),
#  (u'flattened', 1),
#  (u'curbed', 1),
#  (u'ruffled', 1),
#  (u'worsened', 1),
#  (u'snagged', 1),
#  (u'waived', 1),
#  (u'uncovered', 1),
#  (u'cooked', 1),
#  (u'implied', 1),
#  (u'overturned', 1)]
