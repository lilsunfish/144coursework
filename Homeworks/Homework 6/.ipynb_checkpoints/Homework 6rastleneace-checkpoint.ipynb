# %% [markdown]
# ## Problem 1
#
# Please find all of the control predicates in the WSJ subpart of the Penn Treebank. I recommend looking for predicates you know are control explicitly and using that to build tree patterns.

# %%
from runTregex import Treebank


pattern = "/.*/ >: /VB/"
dir = "/Users/ibersue/Documents/Computational Methods /144coursework/Homeworks/Homework 6/treebank_3/parsed/mrg/wsj/"

t = Treebank(dir,pattern)
t.run()

# %%
print len(t)

# %% [markdown]
# ## Problem 2
#
# Please produce a table showing, for the top 50 verbs in WSJ subpart of the Penn Treebank, how many times each verb appears in the active, the passive without a by phrase, and the passive with a by phrase.
#
# For example, the table might have a line like the following (after the header):
#
# <table><tr><th>Verb</th><th>Active</th><th>Passive No By</th><th>Passive By</th></tr>
#
# <tr><th>be</th><th>22818</th><th>12</th><th>56</th></tr>
# <tr><th>have</th><th>10171</th><th>12</th><th>56</th></tr>
# <tr><th>say</th><th>10600</th><th>12</th><th>56</th></tr>
# <tr><th>do</th><th>2641</th><th>12</th><th>56</th></tr>
# <tr><th>make</th><th>1988</th><th>12</th><th>56</th></tr>
# <tr><th>sell</th><th>1387</th><th>12</th><th>56</th></tr>
# <tr><th>take</th><th>1263</th><th>12</th><th>56</th></tr>
# <tr><th>expect</th><th>1209</th><th>12</th><th>56</th></tr>
# <tr><th>include</th><th>1083</th><th>12</th><th>56</th></tr>
# <tr><th>rose</th><th>1071</th><th>12</th><th>56</th></tr>
# <tr><th>get</th><th>1054</th><th>12</th><th>56</th></tr>
# <tr><th>buy</th><th>975</th><th>12</th><th>56</th></tr>
# <tr><th>use</th><th>909</th><th>12</th><th>56</th></tr>
# <tr><th>fall</th><th>742</th><th>12</th><th>56</th></tr>
# <tr><th>report</th><th>732</th><th>12</th><th>56</th></tr>
# <tr><th>add</th><th>706</th><th>12</th><th>56</th></tr>
# <tr><th>close</th><th>619</th><th>12</th><th>56</th></tr>
# <tr><th>think</th><th>594</th><th>12</th><th>56</th></tr>
# <tr><th>end</th><th>558</th><th>12</th><th>56</th></tr>
# <tr><th>base</th><th>403</th><th>12</th><th>56</th></tr>
# </table>

# %%
from runTregex import Treebank


pattern = "/.*/ >: /VB/"
dir = "/Users/ibersue/Documents/Computational Methods /144coursework/Homeworks/Homework 6/treebank_3/parsed/mrg/wsj/"

t = Treebank(dir,pattern)
t.run()
# Out:
# Running tregex...
# Processing output...
# Done!

# %%
print len(t.trees)
# Out:
# 154975

# %%
freqDict = {} 
for tree in t.trees: 
    word = tree.matchTree
    if word not in freqDict:             
        freqDict[word] = 1
    else:
        freqDict[word] += 1
    

sorted(freqDict.items(), key=lambda item: item[1], reverse=True)
# Out:
# [(u'is', 8497),
#  (u'said', 7132),
#  (u'was', 4895),
#  (u'be', 4579),
#  (u'are', 4504),
#  (u'has', 4036),
#  (u'have', 3776),
#  (u'says', 2431),
#  (u'were', 2412),
#  (u'had', 2209),
#  (u'been', 1969),
#  (u"'s", 1490),
#  (u'do', 1156),
#  (u'say', 870),
#  (u'rose', 809),
#  (u'made', 792),
#  (u'did', 743),
#  (u'make', 726),
#  (u'expected', 629),
#  (u'does', 601),
#  (u'get', 563),
#  (u'sold', 558),
#  (u'sell', 552),
#  (u'buy', 548),
#  (u'fell', 535),
#  (u'reported', 528),
#  (u'including', 511),
#  (u'take', 509),
#  (u'used', 493),
#  (u'being', 490),
#  (u"'re", 427),
#  (u'closed', 421),
#  (u'based', 394),
#  (u'added', 391),
#  (u'ended', 384),
#  (u'think', 384),
#  (u'according', 381),
#  (u'pay', 378),
#  (u'going', 375),
#  (u'called', 365),
#  (u'led', 364),
#  (u'agreed', 363),
#  (u'see', 348),
#  (u'held', 345),
#  (u'want', 344),
#  (u'compared', 330),
#  (u'put', 328),
#  (u'paid', 322),
#  (u'go', 320),
#  (u'set', 318),
#  (u'continue', 317),
#  (u'expects', 316),
#  (u'declined', 304),
#  (u'increased', 303),
#  (u'offered', 303),
#  (u'priced', 303),
#  (u'announced', 299),
#  (u'help', 287),
#  (u'come', 285),
#  (u'become', 284),
#  (u'filed', 276),
#  (u'give', 274),
#  (u'took', 271),
#  (u'making', 264),
#  (u'began', 261),
#  (u'owned', 260),
#  (u'yield', 258),
#  (u'received', 253),
#  (u'know', 253),
#  (u'dropped', 250),
#  (u'cut', 244),
#  (u'came', 243),
#  (u'approved', 243),
#  (u'named', 242),
#  (u'taken', 241),
#  (u'include', 240),
#  (u'caused', 236),
#  (u'expect', 236),
#  (u'told', 235),
#  (u'trying', 234),
#  (u'proposed', 231),
#  (u'found', 229),
#  (u'keep', 227),
#  (u'hurt', 226),
#  (u'provide', 219),
#  (u'got', 219),
#  (u'selling', 217),
#  (u"'ve", 215),
#  (u'acquired', 214),
#  (u'estimated', 210),
#  (u'buying', 209),
#  (u'plans', 208),
#  (u'use', 208),
#  (u'makes', 206),
#  (u'run', 206),
#  (u'helped', 206),
#  (u'lost', 202),
#  (u'believe', 202),
#  (u'bought', 197),
#  (u'getting', 196),
#  (u'issued', 191),
#  (u'operating', 190),
#  (u'backed', 190),
#  (u'reached', 187),
#  (u'included', 187),
#  (u'followed', 186),
#  (u'offset', 186),
#  (u'raised', 185),
#  (u'created', 181),
#  (u'raise', 181),
#  (u'find', 180),
#  (u'asked', 178),
#  (u'produced', 178),
#  (u'need', 177),
#  (u'reduce', 176),
#  (u'posted', 176),
#  (u'remain', 175),
#  (u'hit', 174),
#  (u'noted', 174),
#  (u'given', 173),
#  (u'continued', 172),
#  (u'holding', 171),
#  (u'left', 169),
#  (u'saying', 167),
#  (u'work', 167),
#  (u'went', 167),
#  (u'looking', 165),
#  (u'following', 164),
#  (u'known', 163),
#  (u'increase', 162),
#  (u'gained', 160),
#  (u'using', 159),
#  (u'remains', 159),
#  (u'completed', 159),
#  (u'begin', 157),
#  (u'turned', 155),
#  (u'considered', 155),
#  (u'wants', 154),
#  (u'disclosed', 153),
#  (u'growing', 153),
#  (u'build', 153),
#  (u'acquire', 153),
#  (u'done', 152),
#  (u'failed', 150),
#  (u'having', 150),
#  (u'started', 150),
#  (u'owns', 150),
#  (u'seems', 150),
#  (u"'m", 149),
#  (u'show', 149),
#  (u'controlled', 148),
#  (u'seeking', 148),
#  (u'taking', 147),
#  (u'look', 146),
#  (u'coming', 146),
#  (u'includes', 145),
#  (u'comment', 144),
#  (u'working', 143),
#  (u'doing', 141),
#  (u'meet', 141),
#  (u'trading', 141),
#  (u'close', 140),
#  (u'seen', 140),
#  (u'offer', 139),
#  (u'allow', 138),
#  (u'scheduled', 137),
#  (u'report', 136),
#  (u'reduced', 136),
#  (u'try', 134),
#  (u'required', 134),
#  (u'adds', 134),
#  (u'needed', 133),
#  (u'developed', 133),
#  (u'earned', 132),
#  (u'brought', 131),
#  (u'traded', 131),
#  (u'opened', 130),
#  (u'sent', 129),
#  (u'involved', 129),
#  (u'designed', 129),
#  (u'became', 129),
#  (u'jumped', 128),
#  (u'showed', 127),
#  (u'headed', 127),
#  (u'receive', 125),
#  (u'provided', 125),
#  (u'hold', 124),
#  (u'seem', 124),
#  (u'built', 124),
#  (u'produce', 123),
#  (u'introduced', 123),
#  (u'seek', 121),
#  (u'thought', 121),
#  (u'move', 120),
#  (u'changed', 120),
#  (u'won', 119),
#  (u'increasing', 116),
#  (u'consider', 116),
#  (u'continues', 116),
#  (u'According', 116),
#  (u'wanted', 116),
#  (u'leading', 116),
#  (u'passed', 115),
#  (u'affected', 114),
#  (u'forced', 114),
#  (u'signed', 114),
#  (u'continuing', 114),
#  (u'feel', 114),
#  (u'related', 114),
#  (u'decided', 113),
#  (u'comes', 112),
#  (u'quoted', 110),
#  (u'sought', 110),
#  (u'fall', 110),
#  (u'believes', 109),
#  (u'let', 109),
#  (u'spent', 109),
#  (u'rise', 109),
#  (u'turn', 109),
#  (u'bring', 108),
#  (u'gave', 107),
#  (u'require', 107),
#  (u'contributed', 106),
#  (u'allowed', 106),
#  (u'change', 105),
#  (u'rising', 105),
#  (u'calls', 105),
#  (u'means', 102),
#  (u'moved', 102),
#  (u'paying', 102),
#  (u'planned', 101),
#  (u'rejected', 101),
#  (u'placed', 101),
#  (u'offering', 101),
#  (u'holds', 100),
#  (u'avoid', 99),
#  (u'cited', 99),
#  (u'improve', 99),
#  (u'running', 98),
#  (u'worked', 97),
#  (u'valued', 97),
#  (u'start', 97),
#  (u'appear', 96),
#  (u'create', 96),
#  (u'spend', 96),
#  (u'resigned', 95),
#  (u'takes', 95),
#  (u'add', 94),
#  (u'support', 93),
#  (u'develop', 93),
#  (u'win', 93),
#  (u'like', 93),
#  (u'provides', 93),
#  (u'climbed', 92),
#  (u'lead', 92),
#  (u'leave', 90),
#  (u'boosted', 90),
#  (u'indicated', 90),
#  (u'cost', 90),
#  (u'covered', 90),
#  (u'totaled', 89),
#  (u'appears', 89),
#  (u'rated', 88),
#  (u'goes', 88),
#  (u'released', 88),
#  (u'adding', 87),
#  (u'elected', 87),
#  (u'stop', 87),
#  (u'beginning', 87),
#  (u'end', 87),
#  (u'moving', 86),
#  (u'prevent', 85),
#  (u'stay', 85),
#  (u'met', 85),
#  (u'purchased', 85),
#  (u'reflecting', 85),
#  (u'maintain', 84),
#  (u'considering', 84),
#  (u'own', 84),
#  (u'hopes', 83),
#  (u'grew', 83),
#  (u'call', 83),
#  (u'giving', 83),
#  (u'boost', 82),
#  (u'read', 82),
#  (u'tell', 82),
#  (u'saw', 81),
#  (u'ordered', 81),
#  (u'managed', 81),
#  (u'launched', 81),
#  (u'reach', 80),
#  (u'believed', 79),
#  (u'supported', 79),
#  (u'gives', 79),
#  (u'triggered', 79),
#  (u'accept', 78),
#  (u'kept', 78),
#  (u'plunged', 77),
#  (u'determined', 77),
#  (u'face', 77),
#  (u'aimed', 77),
#  (u'carry', 77),
#  (u'attributed', 77),
#  (u'falling', 76),
#  (u'charged', 76),
#  (u'tried', 76),
#  (u'gets', 76),
#  (u'remaining', 75),
#  (u'purchase', 75),
#  (u'raising', 75),
#  (u'needs', 75),
#  (u'prepared', 75),
#  (u'represents', 74),
#  (u'played', 74),
#  (u'cover', 74),
#  (u'established', 74),
#  (u'grow', 74),
#  (u'shows', 73),
#  (u'lose', 73),
#  (u'advanced', 73),
#  (u'return', 73),
#  (u'play', 72),
#  (u'expand', 72),
#  (u'building', 72),
#  (u'opposed', 71),
#  (u'existing', 71),
#  (u'improved', 71),
#  (u'ending', 71),
#  (u'settled', 71),
#  (u'wrote', 71),
#  (u'mean', 70),
#  (u'open', 69),
#  (u'agree', 69),
#  (u'involving', 69),
#  (u'seemed', 68),
#  (u'finance', 68),
#  (u'result', 67),
#  (u'suggested', 67),
#  (u'predicted', 67),
#  (u'declining', 67),
#  (u'listed', 66),
#  (u'remained', 66),
#  (u'stopped', 66),
#  (u'putting', 66),
#  (u'waiting', 66),
#  (u'pending', 66),
#  (u'thinks', 65),
#  (u'preferred', 65),
#  (u'shown', 65),
#  (u'developing', 65),
#  (u'pushed', 65),
#  (u'surged', 65),
#  (u'felt', 65),
#  (u'limited', 65),
#  (u'protect', 65),
#  (u'soared', 65),
#  (u'ease', 64),
#  (u'decide', 64),
#  (u'accused', 64),
#  (u'appeared', 64),
#  (u'starting', 64),
#  (u'managing', 64),
#  (u'leaving', 64),
#  (u'formed', 63),
#  (u'gone', 63),
#  (u'joined', 63),
#  (u'hope', 63),
#  (u'drop', 63),
#  (u'adopted', 63),
#  (u'operate', 63),
#  (u'reflect', 63),
#  (u'voted', 62),
#  (u'runs', 62),
#  (u'ask', 62),
#  (u'described', 62),
#  (u'reflects', 62),
#  (u'entered', 62),
#  (u'conducted', 62),
#  (u'follows', 62),
#  (u'talking', 62),
#  (u'stand', 62),
#  (u'losing', 61),
#  (u'producing', 61),
#  (u'reflected', 61),
#  (u'operates', 61),
#  (u'faces', 61),
#  (u'succeeded', 61),
#  (u'written', 61),
#  (u'accepted', 61),
#  (u'compiled', 61),
#  (u'revised', 60),
#  (u'confirmed', 60),
#  (u'happen', 60),
#  (u'discovered', 60),
#  (u'bid', 60),
#  (u'affect', 60),
#  (u'suffered', 60),
#  (u'suspended', 60),
#  (u'declared', 60),
#  (u'represent', 60),
#  (u'sells', 60),
#  (u'returned', 59),
#  (u'calculated', 59),
#  (u'force', 59),
#  (u'cause', 59),
#  (u'suggest', 59),
#  (u'follow', 59),
#  (u'prompted', 58),
#  (u'showing', 58),
#  (u'trade', 58),
#  (u'replace', 57),
#  (u'plan', 57),
#  (u'expressed', 57),
#  (u'adjusted', 57),
#  (u'denied', 57),
#  (u'fixed', 57),
#  (u'represented', 57),
#  (u'offers', 57),
#  (u'carried', 57),
#  (u'argue', 56),
#  (u'keeping', 56),
#  (u'prove', 56),
#  (u'providing', 56),
#  (u'served', 56),
#  (u'finished', 56),
#  (u'happened', 56),
#  (u'invest', 56),
#  (u'suggests', 56),
#  (u'slipped', 55),
#  (u'spending', 55),
#  (u'block', 55),
#  (u'notes', 55),
#  (u'serve', 55),
#  (u'refused', 55),
#  (u'disclose', 55),
#  (u'damaged', 54),
#  (u'manufacturing', 54),
#  (u'representing', 54),
#  (u'citing', 54),
#  (u'slowing', 54),
#  (u'live', 54),
#  (u'hired', 54),
#  (u'save', 54),
#  (u'appointed', 54),
#  (u'intended', 54),
#  (u'encouraged', 54),
#  (u'settle', 53),
#  (u'asking', 53),
#  (u'caught', 53),
#  (u'ruled', 53),
#  (u'tend', 53),
#  (u'argued', 53),
#  (u'published', 53),
#  (u'fallen', 53),
#  (u'associated', 53),
#  (u'pursue', 52),
#  (u'combined', 52),
#  (u'viewed', 52),
#  (u'handle', 52),
#  (u'tumbled', 52),
#  (u'succeeds', 52),
#  (u'gain', 52),
#  (u'closing', 52),
#  (u'attract', 52),
#  (u'focus', 52),
#  (u'decline', 52),
#  (u'concluded', 52),
#  (u'obtain', 52),
#  (u'intends', 51),
#  (u'am', 51),
#  (u'puts', 51),
#  (u'lowered', 51),
#  (u'cutting', 51),
#  (u'join', 51),
#  (u'begun', 51),
#  (u'push', 50),
#  (u'awarded', 50),
#  (u'indicate', 49),
#  (u'discuss', 49),
#  (u'uses', 49),
#  (u'replaced', 49),
#  (u'warned', 49),
#  (u'claimed', 49),
#  (u'faced', 49),
#  (u'knows', 49),
#  (u'fueled', 48),
#  (u'pass', 48),
#  (u'worry', 48),
#  (u'learned', 48),
#  (u'understand', 48),
#  (u'works', 48),
#  (u'negotiating', 48),
#  (u'hear', 48),
#  (u'acquiring', 48),
#  (u'succeed', 48),
#  (u'urged', 48),
#  (u'looks', 48),
#  (u'extend', 47),
#  (u'invested', 47),
#  (u'concerned', 47),
#  (u'resulting', 47),
#  (u'break', 47),
#  (u'expanding', 47),
#  (u'guaranteed', 47),
#  (u'requires', 47),
#  (u'filled', 47),
#  (u'extended', 47),
#  (u'handled', 47),
#  (u'creating', 47),
#  (u'helping', 47),
#  (u'tied', 46),
#  (u'realize', 46),
#  (u'control', 46),
#  (u'resume', 46),
#  (u'sees', 46),
#  (u'grown', 46),
#  (u'claims', 46),
#  (u'talk', 46),
#  (u'deliver', 46),
#  (u'ensure', 46),
#  (u'driven', 46),
#  (u'alleged', 46),
#  (u'pulled', 45),
#  (u'vote', 45),
#  (u'slow', 45),
#  (u'act', 45),
#  (u'pick', 45),
#  (u'approve', 45),
#  (u'write', 45),
#  (u'benefit', 45),
#  (u'dominated', 45),
#  (u'turning', 45),
#  (u'file', 45),
#  (u'approached', 45),
#  (u'estimates', 45),
#  (u'seeks', 45),
#  (u'measured', 45),
#  (u'pushing', 45),
#  (u'contends', 45),
#  (u'threatened', 44),
#  (u'reducing', 44),
#  (u'resulted', 44),
#  (u'spread', 44),
#  (u'employed', 44),
#  (u'facing', 44),
#  (u'ran', 44),
#  (u'criticized', 44),
#  (u'bringing', 43),
#  (u'expanded', 43),
#  (u'becoming', 43),
#  (u'heard', 43),
#  (u'assume', 43),
#  (u'predict', 43),
#  (u'supposed', 43),
#  (u'calling', 43),
#  (u'sustained', 43),
#  (u'setting', 43),
#  (u'financed', 43),
#  (u'surprised', 42),
#  (u'recorded', 42),
#  (u'issue', 42),
#  (u'insured', 42),
#  (u'allowing', 42),
#  (u'owed', 41),
#  (u'slid', 41),
#  (u'promised', 41),
#  (u'complained', 41),
#  (u'becomes', 41),
#  (u'limit', 41),
#  (u'died', 41),
#  (u'eliminate', 41),
#  (u'identified', 41),
#  (u'retain', 41),
#  (u'insist', 41),
#  (u'looked', 41),
#  (u'planning', 41),
#  (u'fear', 41),
#  (u'carries', 41),
#  (u'estimate', 40),
#  (u'causing', 40),
#  (u'imposed', 40),
#  (u'indicates', 40),
#  (u'fight', 40),
#  (u'presented', 40),
#  (u'committed', 40),
#  (u'seeing', 40),
#  (u'reporting', 40),
#  (u'announce', 40),
#  (u'establish', 40),
#  (u'recalls', 40),
#  (u'determine', 40),
#  (u'achieved', 40),
#  (u'encourage', 39),
#  (u'accompanied', 39),
#  (u'shut', 39),
#  (u'negotiated', 39),
#  (u'blamed', 39),
#  (u'financing', 39),
#  (u'plummeted', 39),
#  (u'wait', 39),
#  (u'distributed', 39),
#  (u'collapsed', 39),
#  (u'account', 39),
#  (u'finding', 39),
#  (u'apply', 39),
#  (u'doubled', 39),
#  (u'exceed', 39),
#  (u'divided', 38),
#  (u'complete', 38),
#  (u'risen', 38),
#  (u'begins', 38),
#  (u'compete', 38),
#  (u'post', 38),
#  (u'introduce', 38),
#  (u'struck', 38),
#  (u'anticipated', 38),
#  (u'surveyed', 38),
#  (u'delivered', 38),
#  (u'explain', 38),
#  (u'identify', 38),
#  (u'advised', 38),
#  (u'killed', 38),
#  (u'founded', 38),
#  (u'regarding', 38),
#  (u'changing', 38),
#  (u'generate', 38),
#  (u'secured', 38),
#  (u'linked', 38),
#  (u'sued', 38),
#  (u'watching', 38),
#  (u'opening', 38),
#  (u'abandoned', 38),
#  (u'costs', 37),
#  (u'occurred', 37),
#  (u'bolstered', 37),
#  (u'delayed', 37),
#  (u'covering', 37),
#  (u'turns', 37),
#  (u'living', 37),
#  (u'totaling', 37),
#  (u'ranging', 36),
#  (u'troubled', 36),
#  (u'Says', 36),
#  (u'broke', 36),
#  (u'submitted', 36),
#  (u'subordinated', 36),
#  (u'protected', 36),
#  (u'enter', 36),
#  (u'permitted', 36),
#  (u'supply', 36),
#  (u'respond', 35),
#  (u'note', 35),
#  (u'worried', 35),
#  (u'selected', 35),
#  (u'send', 35),
#  (u'assumed', 35),
#  (u'accounted', 35),
#  (u'meant', 35),
#  (u'attempting', 35),
#  (u'requiring', 35),
#  (u'recovered', 35),
#  (u'match', 35),
#  (u'aided', 35),
#  (u'involve', 35),
#  (u'deal', 35),
#  (u'hoped', 35),
#  (u'expire', 35),
#  (u'Is', 35),
#  (u'convicted', 35),
#  (u'recommended', 34),
#  (u'authorized', 34),
#  (u'watched', 34),
#  (u'fly', 34),
#  (u'forecast', 34),
#  (u'defend', 34),
#  (u'demand', 34),
#  (u'fighting', 34),
#  (u'funded', 33),
#  (u'learn', 33),
#  (u'dismissed', 33),
#  (u'carrying', 33),
#  (u'buoyed', 33),
#  (u'total', 33),
#  (u'oppose', 33),
#  (u'responded', 33),
#  (u'occur', 33),
#  (u'recover', 33),
#  (u'investing', 33),
#  (u'convert', 33),
#  (u'manage', 33),
#  (u'exceeded', 33),
#  (u'contend', 33),
#  (u'attached', 33),
#  (u'dealing', 33),
#  (u'Do', 33),
#  (u'stood', 33),
#  (u'resolved', 33),
#  (u'acknowledged', 33),
#  (u'charge', 33),
#  (u'cleared', 33),
#  (u'review', 33),
#  (u'kill', 33),
#  (u'discussed', 33),
#  (u'promote', 33),
#  (u'requested', 33),
#  (u'eased', 33),
#  (u'fired', 33),
#  (u'engaged', 32),
#  (u'sparked', 32),
#  (u'hoping', 32),
#  (u'indicating', 32),
#  (u'halted', 32),
#  (u'capped', 32),
#  (u'canceled', 32),
#  (u'competing', 32),
#  (u'draw', 32),
#  (u'earn', 32),
#  (u'manages', 32),
#  (u'suffer', 32),
#  (u'remove', 32),
#  (u'fill', 32),
#  (u'watch', 32),
#  (u'slowed', 32),
#  (u'vary', 31),
#  (u'merge', 31),
#  (u'compares', 31),
#  (u'restructuring', 31),
#  (u'hampered', 31),
#  (u'launch', 31),
#  (u'happens', 31),
#  (u'telling', 31),
#  (u'argues', 31),
#  (u'maintained', 31),
#  (u'revive', 31),
#  (u'beat', 31),
#  (u'noting', 31),
#  (u'charging', 31),
#  (u'borrowed', 31),
#  (u'head', 31),
#  (u'discussing', 31),
#  (u'spurred', 30),
#  (u'proved', 30),
#  (u'afford', 30),
#  (u'drive', 30),
#  (u'delay', 30),
#  (u'realized', 30),
#  (u'obtained', 30),
#  (u'marketing', 30),
#  (u'renewed', 30),
#  (u'fined', 30),
#  (u'sponsored', 30),
#  (u'playing', 30),
#  (u'dropping', 30),
#  (u'applied', 30),
#  (u'insisted', 30),
#  (u'allows', 30),
#  (u'lower', 30),
#  (u'sit', 30),
#  (u'view', 30),
#  (u'favor', 30),
#  (u'elaborate', 29),
#  (u'split', 29),
#  (u'exist', 29),
#  (u'prefer', 29),
#  (u'knew', 29),
#  (u'heads', 29),
#  (u'registered', 29),
#  (u'permit', 29),
#  (u'battered', 29),
#  (u'wonder', 29),
#  (u'broken', 29),
#  (u'share', 29),
#  (u'joining', 29),
#  (u'rallied', 29),
#  (u'helps', 29),
#  (u'controls', 29),
#  (u'leaves', 29),
#  (u'attracted', 29),
#  (u'imported', 29),
#  (u'generated', 29),
#  (u'choose', 29),
#  (u'urging', 29),
#  (u'incurred', 29),
#  (u'reports', 28),
#  (u'organized', 28),
#  (u'participate', 28),
#  (u'succeeding', 28),
#  (u'raises', 28),
#  (u'matched', 28),
#  (u'concentrate', 28),
#  (u'dumped', 28),
#  (u'market', 28),
#  (u'eliminated', 28),
#  (u'form', 28),
#  (u'referring', 28),
#  (u'expecting', 28),
#  (u'purchasing', 28),
#  (u'recognized', 28),
#  (u'tells', 28),
#  (u'retire', 28),
#  (u'underlying', 28),
#  (u'excluding', 28),
#  (u'assuming', 28),
#  (u'supplied', 28),
#  (u'rebounded', 28),
#  (u'deny', 28),
#  (u'attended', 28),
#  (u'place', 28),
#  (u'complain', 28),
#  (u'influenced', 28),
#  (u'shared', 28),
#  (u'bolster', 28),
#  (u'shipping', 28),
#  (u'explained', 27),
#  (u'fail', 27),
#  (u'squeezed', 27),
#  (u'restricted', 27),
#  (u'retained', 27),
#  (u'banned', 27),
#  (u'insists', 27),
#  (u'studying', 27),
#  (u'Asked', 27),
#  (u'pays', 27),
#  (u'receiving', 27),
#  (u'blame', 27),
#  (u'informed', 27),
#  (u'focused', 27),
#  (u'mentioned', 27),
#  (u'restore', 27),
#  (u'tracked', 27),
#  (u'pointed', 27),
#  (u'projected', 27),
#  (u'gotten', 27),
#  (u'resolve', 27),
#  (u'meeting', 27),
#  (u'back', 27),
#  (u'catch', 27),
#  (u'leads', 27),
#  (u'explains', 27),
#  (u'Rated', 26),
#  (u'transferred', 26),
#  (u'sat', 26),
#  (u'borrow', 26),
#  (u'interviewed', 26),
#  (u'preparing', 26),
#  (u'struggling', 26),
#  (u'Guaranteed', 26),
#  (u'supporting', 26),
#  (u'retired', 26),
#  (u'hire', 26),
#  (u'reject', 26),
#  (u'picked', 26),
#  (u'expires', 26),
#  (u'operated', 26),
#  (u'survive', 26),
#  (u'failing', 26),
#  (u'predicting', 26),
#  (u'flying', 26),
#  (u'claim', 26),
#  (u'monitor', 26),
#  (u'acting', 26),
#  (u'point', 26),
#  (u'exercise', 26),
#  (u'Posted', 26),
#  (u'notified', 26),
#  (u'stands', 26),
#  (u'pleaded', 26),
#  (u'performed', 26),
#  (u'press', 26),
#  (u'conceded', 25),
#  (u'targeted', 25),
#  (u'produces', 25),
#  (u'chosen', 25),
#  (u'depends', 25),
#  (u'lies', 25),
#  (u'sign', 25),
#  (u'increases', 25),
#  (u'reaching', 25),
#  (u'happening', 25),
#  (u'shift', 25),
#  (u'stepped', 25),
#  (u'mixed', 25),
#  (u'sitting', 25),
#  (u'injured', 25),
#  (u'driving', 25),
#  (u'ignored', 25),
#  (u'last', 25),
#  (u'shipped', 24),
#  (u'concedes', 24),
#  (u'improving', 24),
#  (u'enable', 24),
#  (u'focusing', 24),
#  (u'mature', 24),
#  (u'reacted', 24),
#  (u'rule', 24),
#  (u'speak', 24),
#  (u'serving', 24),
#  (u'enacted', 24),
#  (u'challenged', 24),
#  (u'thinking', 24),
#  (u'endorsed', 24),
#  (u'emerging', 24),
#  (u'contain', 24),
#  (u'asks', 24),
#  (u'covers', 24),
#  (u'signaled', 24),
#  (u'assist', 24),
#  (u'disappointed', 24),
#  (u'confirm', 24),
#  (u'arranged', 24),
#  (u'feared', 24),
#  (u'winning', 24),
#  (u'visited', 24),
#  (u'admitted', 24),
#  (u'wish', 24),
#  (u'persuade', 24),
#  (u'writing', 24),
#  (u'stated', 24),
#  (u'discontinued', 24),
#  (u'adopt', 24),
#  (u'violated', 24),
#  (u'topped', 24),
#  (u'travel', 23),
#  (u'unveiled', 23),
#  (u'suggesting', 23),
#  (u'edged', 23),
#  (u'installed', 23),
#  (u'handling', 23),
#  (u'predicts', 23),
#  (u'marked', 23),
#  (u'consulting', 23),
#  (u'care', 23),
#  (u'benefited', 23),
#  (u'forcing', 23),
#  (u'tendered', 23),
#  (u'experienced', 23),
#  (u'missing', 23),
#  (u'jump', 23),
#  (u'averaged', 23),
#  (u'located', 23),
#  (u'achieve', 23),
#  (u'drew', 23),
#  (u'surrounding', 23),
#  (u'amounted', 23),
#  (u'emerged', 23),
#  (u'investigating', 23),
#  (u'specified', 23),
#  (u'curb', 23),
#  (u'executed', 23),
#  (u'boosting', 23),
#  (u'restrict', 23),
#  (u'impose', 23),
#  (u'cast', 23),
#  (u'declines', 23),
#  (u'finds', 23),
#  (u'sending', 23),
#  (u'negotiate', 23),
#  (u'seized', 23),
#  (u'agrees', 23),
#  (u'converted', 23),
#  (u'transfer', 23),
#  (u'address', 22),
#  (u'contained', 22),
#  (u'affecting', 22),
#  (u'pull', 22),
#  (u'accounts', 22),
#  (u'fund', 22),
#  (u'defined', 22),
#  (u'involves', 22),
#  (u'recognize', 22),
#  (u'study', 22),
#  (u'veto', 22),
#  (u'admits', 22),
#  (u'weakened', 22),
#  (u'filing', 22),
#  (u'publish', 22),
#  (u'sentenced', 22),
#  (u'stem', 22),
#  (u'step', 22),
#  (u'plays', 22),
#  (u'starts', 22),
#  (u'Consider', 22),
#  (u'points', 22),
#  (u'easing', 22),
#  (u'maturing', 22),
#  (u'withdraw', 22),
#  (u'lend', 22),
#  (u'sets', 22),
#  (u'withdrew', 22),
#  (u'repeated', 22),
#  (u'claiming', 22),
#  (u'rely', 22),
#  (u'figure', 22),
#  (u'profit', 22),
#  (u'featuring', 22),
#  (u'justify', 22),
#  (u'proceed', 22),
#  (u'strengthen', 22),
#  (u'depending', 22),
#  (u'range', 22),
#  (u'strike', 21),
#  (u'studied', 21),
#  (u'complicated', 21),
#  (u'tested', 21),
#  (u'knocked', 21),
#  (u'rumored', 21),
#  (u'dubbed', 21),
#  (u'restructure', 21),
#  (u'contribute', 21),
#  (u'pursuing', 21),
#  (u'perform', 21),
#  (u'denies', 21),
#  (u'Let', 21),
#  (u'underwritten', 21),
#  (u'charges', 21),
#  (u'intend', 21),
#  (u'prepare', 21),
#  (u'moves', 21),
#  (u'inspired', 21),
#  (u'advertising', 21),
#  (u'referred', 21),
#  (u'surrounded', 21),
#  (u'feels', 21),
#  (u'lived', 21),
#  (u'overcome', 21),
#  (u'die', 21),
#  (u'shot', 21),
#  (u'eliminating', 21),
#  (u'killing', 21),
#  (u'employs', 21),
#  (u'arguing', 21),
#  (u'donated', 21),
#  (u'check', 21),
#  (u'promoting', 21),
#  (u'emerge', 21),
#  (u'specify', 21),
#  (u'falls', 21),
#  (u'buys', 21),
#  (u'double', 21),
#  (u'painted', 21),
#  (u'preserve', 20),
#  (u'shaken', 20),
#  (u'considers', 20),
#  (u'sank', 20),
#  (u'initiated', 20),
#  (u'seize', 20),
#  (u'diluted', 20),
#  (u'redeemed', 20),
#  (u'invited', 20),
#  (u'combine', 20),
#  (u'lifted', 20),
#  (u'drawn', 20),
#  (u'attacked', 20),
#  (u'promises', 20),
#  (u'switched', 20),
#  (u'stayed', 20),
#  (u'repay', 20),
#  (u'favored', 20),
#  (u'marketed', 20),
#  (u'announcing', 20),
#  (u'treat', 20),
#  (u'prohibited', 20),
#  (u'arrested', 20),
#  (u'mandated', 20),
#  (u'amended', 20),
#  (u'regarded', 20),
#  (u'restored', 20),
#  (u'talked', 20),
#  (u'serves', 20),
#  (u'controlling', 20),
#  (u'directed', 20),
#  (u'explaining', 20),
#  (u'hammered', 20),
#  (u'enhanced', 20),
#  (u'violate', 20),
#  (u'kicked', 20),
#  (u'participating', 20),
#  (u'removed', 20),
#  (u'widened', 20),
#  (u'qualify', 20),
#  (u'ignoring', 20),
#  (u'question', 20),
#  (u'chose', 20),
#  (u'remember', 20),
#  (u'narrowed', 20),
#  (u'ruling', 20),
#  (u'welcomed', 19),
#  (u'lift', 19),
#  (u'maintaining', 19),
#  (u'slashed', 19),
#  (u'refuse', 19),
#  (u'barred', 19),
#  (u'defended', 19),
#  (u'submit', 19),
#  (u'counted', 19),
#  (u'Excluding', 19),
#  (u'figures', 19),
#  (u'consisting', 19),
#  (u'disputed', 19),
#  (u'creates', 19),
#  (u'exercised', 19),
#  (u'enjoyed', 19),
#  (u'born', 19),
#  (u'responding', 19),
#  (u'interested', 19),
#  (u'drove', 19),
#  (u'stems', 19),
#  (u'speed', 19),
#  (u'throw', 19),
#  (u'tries', 19),
#  (u'oversees', 19),
#  (u'resumed', 19),
#  (u'expired', 19),
#  (u'posting', 19),
#  (u'signal', 19),
#  (u'ignore', 19),
#  (u'agreeing', 19),
#  (u'marks', 19),
#  (u'attracting', 19),
#  (u'Having', 19),
#  (u'fend', 19),
#  (u'solve', 19),
#  (u'merged', 19),
#  (u'letting', 19),
#  (u'mention', 19),
#  (u'owning', 19),
#  (u'acknowledges', 19),
#  (u'accommodate', 19),
#  (u'stuck', 19),
#  (u'fought', 19),
#  (u'stabilize', 19),
#  (u'vowed', 19),
#  (u'quit', 19),
#  (u'stemming', 19),
#  (u'regulated', 19),
#  (u'stolen', 19),
#  (u'arrived', 19),
#  (u'interpreted', 19),
#  (u'fled', 19),
#  (u'walk', 19),
#  (u'spoke', 18),
#  (u'reviewing', 18),
#  (u'rolled', 18),
#  (u'drafted', 18),
#  (u'reopen', 18),
#  (u'contended', 18),
#  (u'banking', 18),
#  (u'challenge', 18),
#  (u'weaken', 18),
#  (u'stalled', 18),
#  (u'equaling', 18),
#  (u'blocking', 18),
#  (u'lay', 18),
#  (u'receives', 18),
#  (u'concerning', 18),
#  (u'appeal', 18),
#  (u'exposed', 18),
#  (u'anticipate', 18),
#  (u'clear', 18),
#  (u'stemmed', 18),
#  (u'diminished', 18),
#  (u'devised', 18),
#  (u'heading', 18),
#  (u'answer', 18),
#  (u'wearing', 18),
#  (u'picking', 18),
#  (u'grows', 18),
#  (u'vacated', 18),
#  (u'handed', 18),
#  (u'switch', 18),
#  (u'indicted', 18),
#  (u'removing', 18),
#  (u'compare', 18),
#  (u'embraced', 18),
#  (u'redeem', 18),
#  (u'snapped', 18),
#  (u'rushed', 18),
#  (u'enjoy', 18),
#  (u'conduct', 18),
#  (u'abandon', 18),
#  (u'granted', 18),
#  (u'speculated', 18),
#  (u'breaking', 18),
#  (u'dump', 18),
#  (u'understood', 18),
#  (u'warning', 18),
#  (u'restructured', 18),
#  (u'acted', 18),
#  (u'brings', 17),
#  (u'export', 17),
#  (u'fit', 17),
#  (u'assured', 17),
#  (u'listen', 17),
#  (u'release', 17),
#  (u'demanded', 17),
#  (u'spin', 17),
#  (u'distribute', 17),
#  (u'shifting', 17),
#  (u'love', 17),
#  (u'yielding', 17),
#  (u'establishing', 17),
#  (u'entering', 17),
#  (u'depressed', 17),
#  (u'restated', 17),
#  (u'adjust', 17),
#  (u'threatening', 17),
#  (u'writes', 17),
#  (u'publishing', 17),
#  (u'pressed', 17),
#  (u'backing', 17),
#  (u'voting', 17),
#  (u'test', 17),
#  (u'perceived', 17),
#  (u'halt', 17),
#  (u'avoided', 17),
#  (u'testify', 17),
#  (u'deciding', 17),
#  (u'reviewed', 17),
#  (u'connected', 17),
#  (u'hiring', 17),
#  (u'absorb', 17),
#  (u'eat', 17),
#  (u'consists', 17),
#  (u'enhance', 17),
#  (u'recommend', 17),
#  (u'Given', 17),
#  (u'assigned', 17),
#  (u'performing', 17),
#  (u'Are', 17),
#  (u'visit', 17),
#  (u'designated', 17),
#  (u'pressing', 17),
#  (u'conducting', 17),
#  (u'ranged', 17),
#  (u'publishes', 17),
#  (u'specializes', 17),
#  (u'funding', 17),
#  (u'assembled', 17),
#  (u'risk', 17),
#  (u'guarantee', 17),
#  (u'banning', 17),
#  (u'advising', 17),
#  (u'wear', 17),
#  (u'blocked', 17),
#  (u'execute', 17),
#  (u'captured', 17),
#  (u'reduces', 17),
#  (u'alter', 17),
#  (u'magnified', 17),
#  (u'polled', 17),
#  (u'collect', 17),
#  (u'shed', 17),
#  (u'engineered', 17),
#  (u'proposing', 17),
#  (u'withdrawn', 17),
#  (u'Following', 17),
#  (u'keeps', 16),
#  (u'absorbed', 16),
#  (u'posed', 16),
#  (u'values', 16),
#  (u'accepting', 16),
#  (u'dragged', 16),
#  (u'relating', 16),
#  (u'disrupted', 16),
#  (u'ordering', 16),
#  (u'ends', 16),
#  (u'figured', 16),
#  (u'conclude', 16),
#  (u'saved', 16),
#  (u'stressed', 16),
#  (u'postponed', 16),
#  (u'commissioned', 16),
#  (u'learning', 16),
#  (u'passing', 16),
#  (u'anticipates', 16),
#  (u'gaining', 16),
#  (u'Take', 16),
#  (u'contains', 16),
#  (u'lowering', 16),
#  (u'exclude', 16),
#  (u'describes', 16),
#  (u'questioned', 16),
#  (u'translated', 16),
#  (u'exceeding', 16),
#  (u'lobbying', 16),
#  (u'ride', 16),
#  (u'escaped', 16),
#  (u'pulling', 16),
#  (u'offsetting', 16),
#  (u'pursued', 16),
#  (u'issuing', 16),
#  (u'upset', 16),
#  (u'deemed', 16),
#  (u'attempt', 16),
#  (u'mind', 16),
#  (u'comply', 16),
#  (u'ban', 16),
#  (u'decides', 16),
#  (u'defeated', 16),
#  (u'ship', 16),
#  (u'suspect', 16),
#  (u'sounds', 16),
#  (u'hailed', 16),
#  (u'reading', 16),
#  (u'manufactured', 16),
#  (u'recall', 16),
#  (u'asserted', 16),
#  (u'stripped', 16),
#  (u'postpone', 16),
#  (u'reaches', 16),
#  (u'bear', 16),
#  (u'returning', 16),
#  (u'prevented', 16),
#  (u'filling', 16),
#  (u'laid', 16),
#  (u'monitored', 16),
#  (u'attempted', 16),
#  (u'name', 16),
#  (u'soaring', 16),
#  (u'cope', 16),
#  (u'tends', 16),
#  (u'upheld', 16),
#  (u'slated', 16),
#  (u'disagree', 16),
#  (u'locked', 15),
#  (u'feeling', 15),
#  (u'pressured', 15),
#  (u'rebuffed', 15),
#  (u'roll', 15),
#  (u'rolling', 15),
#  (u'solved', 15),
#  (u'concentrated', 15),
#  (u'oust', 15),
#  (u'mounting', 15),
#  (u'concede', 15),
#  (u'spooked', 15),
#  (u'retains', 15),
#  (u'recommends', 15),
#  (u'causes', 15),
#  (u'speculate', 15),
#  (u'missed', 15),
#  (u'guess', 15),
#  (u'owes', 15),
#  (u'plagued', 15),
#  (u'engage', 15),
#  (u'standing', 15),
#  (u'doubt', 15),
#  (u'lock', 15),
#  (u'vetoed', 15),
#  (u'leveraged', 15),
#  (u'terminated', 15),
#  (u'observed', 15),
#  (u'satisfy', 15),
#  (u'sweetened', 15),
#  (u'throwing', 15),
#  (u'likes', 15),
#  (u'evaluate', 15),
#  (u'persuaded', 15),
#  (u'lives', 15),
#  (u'implemented', 15),
#  (u'replacing', 15),
#  (u'threw', 15),
#  (u'Estimated', 15),
#  (u'depend', 15),
#  (u'praised', 15),
#  (u'correct', 15),
#  (u'waited', 15),
#  (u'pegged', 15),
#  (u'dated', 15),
#  (u'sound', 15),
#  (u'pleased', 15),
#  (u'retiring', 15),
#  (u'resisted', 15),
#  (u'revived', 15),
#  (u'slipping', 15),
#  (u'protecting', 15),
#  (u'contracted', 15),
#  (u'Using', 15),
#  (u'processed', 15),
#  (u'reveal', 15),
#  (u'spends', 15),
#  (u'stick', 15),
#  (u'thrown', 15),
#  (u'convinced', 15),
#  (u'advise', 15),
#  (u'explore', 15),
#  (u'settling', 15),
#  (u'integrated', 15),
#  (u'reversed', 15),
#  (u'limiting', 15),
#  (u'spur', 15),
#  (u'rocked', 15),
#  (u'record', 15),
#  (u'launching', 14),
#  (u'introducing', 14),
#  (u'cite', 14),
#  (u'spark', 14),
#  (u'appealed', 14),
#  (u'replied', 14),
#  (u'termed', 14),
#  (u'singled', 14),
#  (u'hitting', 14),
#  (u'alleging', 14),
#  (u'repair', 14),
#  (u'influence', 14),
#  (u'reopened', 14),
#  (u'experiencing', 14),
#  (u'cheered', 14),
#  (u'counter', 14),
#  (u'strengthened', 14),
#  (u'recovering', 14),
#  (u'target', 14),
#  (u'reacting', 14),
#  (u'omitted', 14),
#  (u'finish', 14),
#  (u'tracks', 14),
#  (u'mounted', 14),
#  (u'lacks', 14),
#  (u'miss', 14),
#  (u'clean', 14),
#  (u'besieged', 14),
#  (u'earmarked', 14),
#  (u'lagged', 14),
#  (u'noticed', 14),
#  (u'warns', 14),
#  (u'taught', 14),
#  (u'consumed', 14),
#  (u'favors', 14),
#  (u'targeting', 14),
#  (u'destroy', 14),
#  (u'scrambling', 14),
#  (u'shake', 14),
#  (u'undermined', 14),
#  (u'broadcast', 14),
#  (u'declares', 14),
#  (u'cancel', 14),
#  (u'climbing', 14),
#  (u'matching', 14),
#  (u'acts', 14),
#  (u'hurting', 14),
#  (u'rebound', 14),
#  (u'fed', 14),
#  (u'assisted', 14),
#  (u'exchange', 14),
#  (u'pouring', 14),
#  (u'regain', 14),
#  (u'constitute', 14),
#  (u'install', 14),
#  (u'destroyed', 14),
#  (u'containing', 14),
#  (u'obtaining', 14),
#  (u'transform', 14),
#  (u'weakening', 14),
#  (u'suspend', 14),
#  (u'cautioned', 14),
#  (u'surfaced', 14),
#  (u'alleges', 14),
#  (u'treating', 14),
#  (u'prompting', 14),
#  (u'relieved', 14),
#  (u'measures', 14),
#  (u'complains', 14),
#  (u'rally', 14),
#  (u'trimmed', 14),
#  (u'present', 14),
#  (u'undertaken', 14),
#  (u'murdered', 14),
#  (u'firmed', 13),
#  (u'contributing', 13),
#  (u'opposes', 13),
#  (u'structured', 13),
#  (u'printed', 13),
#  (u'Looking', 13),
#  (u'unveil', 13),
#  (u'detailed', 13),
#  (u'occurs', 13),
#  (u'imagine', 13),
#  (u'repaid', 13),
#  (u'opens', 13),
#  (u'gathered', 13),
#  (u'asserts', 13),
#  (u'riding', 13),
#  (u'discounted', 13),
#  (u'assess', 13),
#  (u'convince', 13),
#  (u'secure', 13),
#  (u'rushing', 13),
#  (u'governed', 13),
#  (u'lending', 13),
#  (u'labeled', 13),
#  (u'repurchase', 13),
#  (u'rebuild', 13),
#  (u'angered', 13),
#  (u'assumes', 13),
#  (u'pledged', 13),
#  (u'renewing', 13),
#  (u'positioned', 13),
#  (u'sustain', 13),
#  (u'ousted', 13),
#  (u'forgotten', 13),
#  (u'processing', 13),
#  (u'addressed', 13),
#  (u'subsidized', 13),
#  (u'scrambled', 13),
#  (u'credited', 13),
#  (u'leased', 13),
#  (u'cuts', 13),
#  (u'interfere', 13),
#  (u'admit', 13),
#  (u'demonstrated', 13),
#  (u'Put', 13),
#  (u'taped', 13),
#  (u'advancing', 13),
#  (u'aging', 13),
#  (u'featured', 13),
#  (u'arrive', 13),
#  (u'staying', 13),
#  (u'trades', 13),
#  (u'meaning', 13),
#  (u'examine', 13),
#  (u'forget', 13),
#  (u'treated', 13),
#  (u'reverse', 13),
#  (u'implies', 13),
#  (u'insisting', 13),
#  (u'earning', 13),
#  (u'measure', 13),
#  (u'shook', 13),
#  (u'demanding', 13),
#  (u'combining', 13),
#  (u'encouraging', 13),
#  (u'hearing', 13),
#  (u'betting', 13),
#  (u'outnumbered', 13),
#  (u'appearing', 13),
#  (u'uncovered', 13),
#  (u'boasts', 13),
#  (u'exploring', 13),
#  (u'urge', 13),
#  (u'imposing', 13),
#  (u'deteriorating', 13),
#  (u'teach', 13),
#  (u'aims', 13),
#  (u'lying', 13),
#  (u'frozen', 13),
#  (u'completing', 13),
#  (u'concludes', 13),
#  (u'accrued', 13),
#  (u'counting', 13),
#  (u'supports', 13),
#  (u'frustrated', 13),
#  (u'scared', 13),
#  (u'wins', 12),
#  (u'diverted', 12),
#  (u'lacked', 12),
#  (u'wondering', 12),
#  (u'monitoring', 12),
#  (u'governing', 12),
#  (u'saving', 12),
#  (u'proving', 12),
#  (u'propose', 12),
#  (u'suffering', 12),
#  (u'inched', 12),
#  (u'preventing', 12),
#  (u'opposing', 12),
#  (u'licensed', 12),
#  (u'invented', 12),
#  (u'defending', 12),
#  (u'drawing', 12),
#  (u'cites', 12),
#  (u'extending', 12),
#  (u'steal', 12),
#  (u'downgraded', 12),
#  (u'exceeds', 12),
#  (u'fared', 12),
#  (u'evidenced', 12),
#  (u'bound', 12),
#  (u'compensate', 12),
#  (u'displayed', 12),
#  (u'exploit', 12),
#  (u'describe', 12),
#  (u'lie', 12),
#  (u'collected', 12),
#  (u'bidding', 12),
#  (u'grant', 12),
#  (u'belong', 12),
#  (u'slash', 12),
#  (u'manufacture', 12),
#  (u'fare', 12),
#  (u'attending', 12),
#  (u'bears', 12),
#  (u'bet', 12),
#  (u'thwarted', 12),
#  (u'swap', 12),
#  (u'features', 12),
#  (u'stepping', 12),
#  (u'tripled', 12),
#  (u'declaring', 12),
#  (u'stabilizing', 12),
#  (u'track', 12),
#  (u'mark', 12),
#  (u'admitting', 12),
#  (u'spreading', 12),
#  (u'lease', 12),
#  (u'weigh', 12),
#  (u'override', 12),
#  (u'burned', 12),
#  (u'honor', 12),
#  (u'stock', 12),
#  (u'curtail', 12),
#  (u'hide', 12),
#  (u'consented', 12),
#  (u'contacted', 12),
#  (u'resigning', 12),
#  (u'fuel', 12),
#  (u'fails', 12),
#  (u'mount', 12),
#  (u'relies', 12),
#  (u'design', 12),
#  (u'store', 12),
#  (u'investigate', 12),
#  (u'impressed', 12),
#  (u'cooperate', 12),
#  (u'violating', 12),
#  (u'flew', 12),
#  (u'maintains', 12),
#  (u'loses', 12),
#  (u'auctioned', 11),
#  (u'caution', 11),
#  (u'complaining', 11),
#  (u'hidden', 11),
#  (u'project', 11),
#  (u'adapted', 11),
#  (u'anticipating', 11),
#  (u'accelerate', 11),
#  (u'proven', 11),
#  (u'accounting', 11),
#  (u"'d", 11),
#  (u'walking', 11),
#  (u'refer', 11),
#  (u'survived', 11),
#  (u'illustrates', 11),
#  (u'prompt', 11),
#  (u'investigated', 11),
#  (u'instituted', 11),
#  (u'knowing', 11),
#  (u'discounting', 11),
#  (u'delivering', 11),
#  (u'retreated', 11),
#  (u'slip', 11),
#  (u'fits', 11),
#  (u'collecting', 11),
#  (u'soar', 11),
#  (u'allocated', 11),
#  (u'count', 11),
#  (u'order', 11),
#  (u'meets', 11),
#  (u'illustrate', 11),
#  (u'loved', 11),
#  (u'aid', 11),
#  (u'disapproved', 11),
#  (u'accomplish', 11),
#  (u'concentrating', 11),
#  (u'staged', 11),
#  (u'coordinate', 11),
#  (u'listening', 11),
#  (u'erode', 11),
#  (u'linking', 11),
#  (u'knocking', 11),
#  (u'aired', 11),
#  (u'damp', 11),
#  (u'crack', 11),
#  (u'guarantees', 11),
#  (u'amounts', 11),
#  (u'revamped', 11),
#  (u'enforce', 11),
#  (u'converting', 11),
#  (u'shaking', 11),
#  (u'reinforce', 11),
#  (u'maximize', 11),
#  (u'discouraged', 11),
#  (u'propelled', 11),
#  (u'shouted', 11),
#  (u'display', 11),
#  (u'interpret', 11),
#  (u'counts', 11),
#  (u'withstand', 11),
#  (u'compounded', 11),
#  (u'testing', 11),
#  (u'commit', 11),
#  (u'builds', 11),
#  (u'marking', 11),
#  (u'advises', 11),
#  (u'avoiding', 11),
#  (u'consolidating', 11),
#  (u'dominate', 11),
#  (u'participated', 11),
#  (u'pump', 11),
#  (u'specializing', 11),
#  (u'resign', 11),
#  (u'unload', 11),
#  (u'withheld', 11),
#  (u'crowded', 11),
#  (u'plead', 11),
#  (u'aged', 11),
#  (u'visiting', 11),
#  (u'scuttle', 11),
#  (u'jolted', 11),
#  (u'prevail', 11),
#  (u'stabilized', 11),
#  (u'arrange', 11),
#  (u'fetch', 11),
#  (u'bothered', 11),
#  (u'slumped', 11),
#  (u'recommending', 11),
#  (u'lure', 11),
#  (u'beaten', 11),
#  (u'preserving', 11),
#  (u'signing', 11),
#  (u'top', 11),
#  (u'regulate', 11),
#  (u'isolated', 11),
#  (u'resist', 11),
#  (u'proposes', 11),
#  (u'eroded', 11),
#  (u'plunging', 11),
#  (u'trim', 11),
#  (u'emphasized', 11),
#  (u'cool', 11),
#  (u'dispatched', 11),
#  (u'hedge', 11),
#  (u'drives', 11),
#  (u'relied', 11),
#  (u'deserve', 11),
#  (u'induce', 11),
#  (u'skidded', 11),
#  (u'challenging', 11),
#  (u'characterized', 11),
#  (u'throws', 11),
#  (u'exploded', 11),
#  (u'analyze', 11),
#  (u'consist', 11),
#  (u'Buying', 11),
#  (u'discourage', 11),
#  (u'searching', 11),
#  (u'promise', 11),
#  (u'waive', 10),
#  (u'touched', 10),
#  (u'summoned', 10),
#  (u'underestimated', 10),
#  (u'overhaul', 10),
#  (u'aroused', 10),
#  (u'undermine', 10),
#  (u'laying', 10),
#  (u'select', 10),
#  (u'corrected', 10),
#  (u'rises', 10),
#  (u'understands', 10),
#  (u'improves', 10),
#  (u'evaluating', 10),
#  (u'flooded', 10),
#  (u'decrease', 10),
#  (u'pour', 10),
#  (u'acquitted', 10),
#  (u'directs', 10),
#  (u'bother', 10),
#  (u'drink', 10),
#  (u'choosing', 10),
#  (u'lasted', 10),
#  (u'permits', 10),
#  (u'appreciate', 10),
#  (u'packaged', 10),
#  (u'sends', 10),
#  (u'Led', 10),
#  (u'liquidated', 10),
#  (u'sagging', 10),
#  (u'gather', 10),
#  (u'discover', 10),
#  (u'teaches', 10),
#  (u'acknowledge', 10),
#  (u'respected', 10),
#  (u'shrinking', 10),
#  (u'pointing', 10),
#  (u'spawned', 10),
#  (u'develops', 10),
#  (u'earns', 10),
#  (u'intensify', 10),
#  (u'ranked', 10),
#  (u'recalled', 10),
#  (u'Declining', 10),
#  (u'describing', 10),
#  (u'reiterated', 10),
#  (u'testified', 10),
#  (u'determining', 10),
#  (u'revealed', 10),
#  (u'joins', 10),
#  (u'spotted', 10),
#  (u'hits', 10),
#  (u'erased', 10),
#  (u'tapped', 10),
#  (u'adopting', 10),
#  (u'stealing', 10),
#  (u'bounced', 10),
#  (u'disappear', 10),
#  (u'entitled', 10),
#  (u'eating', 10),
#  (u'emerges', 10),
#  (u'speaking', 10),
#  (u'voiced', 10),
#  (u'soliciting', 10),
#  (u'finishing', 10),
#  (u'dipped', 10),
#  (u'distracted', 10),
#  (u'wiped', 10),
#  (u'landed', 10),
#  (u'questioning', 10),
#  (u'detected', 10),
#  (u'distributes', 10),
#  (u'scrapped', 10),
#  (u'denying', 10),
#  (u'strapped', 10),
#  (u'lent', 10),
#  (u'climb', 10),
#  (u'lagging', 10),
#  (u'conform', 10),
#  (u'exists', 10),
#  (u'clearing', 10),
#  (u'tighten', 10),
#  (u'hate', 10),
#  (u'supplies', 10),
#  (u'Annualized', 10),
#  (u'consolidate', 10),
#  (u'prohibit', 10),
#  (u'blames', 10),
#  (u'underwrite', 10),
#  (u'approach', 10),
#  (u'belongs', 10),
#  (u'casting', 10),
#  (u'greeted', 10),
#  (u'escape', 10),
#  (u'existed', 10),
#  (u'reconsider', 10),
#  (u'handles', 10),
#  (u'circulated', 10),
#  (u'coupled', 10),
#  (u'lack', 10),
#  (u'sue', 10),
#  (u'shore', 10),
#  (u'react', 10),
#  (u'hinted', 10),
#  (u'modernize', 10),
#  (u'plunge', 10),
#  (u'barring', 10),
#  (u'overseeing', 10),
#  (u'Based', 10),
#  (u'scaled', 10),
#  (u'tap', 10),
#  (u'struggled', 10),
#  (u'spun', 10),
#  (u'acquires', 10),
#  (u'enact', 10),
#  (u'squeeze', 10),
#  (u'Does', 9),
#  (u'infringed', 9),
#  (u'designing', 9),
#  (u'relax', 9),
#  (u'undercut', 9),
#  (u'service', 9),
#  (u'touting', 9),
#  (u'derived', 9),
#  (u'retaining', 9),
#  (u'nominated', 9),
#  (u'gauge', 9),
#  (u'doubts', 9),
#  (u'enters', 9),
#  (u"'S", 9),
#  (u'bribed', 9),
#  (u'decreased', 9),
#  (u'spoken', 9),
#  (u'addressing', 9),
#  (u'translate', 9),
#  (u'wanting', 9),
#  (u'awaiting', 9),
#  (u'curbing', 9),
#  (u'puzzled', 9),
#  (u'neglected', 9),
#  (u'states', 9),
#  (u'resemble', 9),
#  (u'implement', 9),
#  (u'link', 9),
#  (u'walked', 9),
#  (u'soften', 9),
#  (u'doubling', 9),
#  (u'fulfill', 9),
#  (u'differ', 9),
#  (u'prohibits', 9),
#  (u'lined', 9),
#  (u'planted', 9),
#  (u'exchanged', 9),
#  (u'crafted', 9),
#  (u'poured', 9),
#  (u'highlighted', 9),
#  (u'pressure', 9),
#  (u'places', 9),
#  (u'repeat', 9),
#  (u'satisfied', 9),
#  (u'renew', 9),
#  (u'draws', 9),
#  (u'widen', 9),
#  (u'inhibit', 9),
#  (u'pose', 9),
#  (u'Make', 9),
#  (u'shrink', 9),
#  (u'welcome', 9),
#  (u'devoted', 9),
#  (u'airing', 9),
#  (u'regained', 9),
#  (u'shares', 9),
#  (u'accelerated', 9),
#  (u'Call', 9),
#  (u'swelled', 9),
#  (u'price', 9),
#  (u'justified', 9),
#  (u'analyzed', 9),
#  (u'enabling', 9),
#  (u'figuring', 9),
#  (u'heightened', 9),
#  (u'balked', 9),
#  (u'inflated', 9),
#  (u'weighed', 9),
#  (u'ratified', 9),
#  (u'motivated', 9),
#  (u'sweeping', 9),
#  (u'curtailed', 9),
#  (u'deter', 9),
#  (u'fears', 9),
#  (u'drops', 9),
#  (u'aggravated', 9),
#  (u'underpinned', 9),
#  (u'inherited', 9),
#  (u'capture', 9),
#  (u'presents', 9),
#  (u'govern', 9),
#  (u'warn', 9),
#  (u'enabled', 9),
#  (u'matter', 9),
#  (u'clobbered', 9),
#  (u'wears', 9),
#  (u'trigger', 9),
#  (u'buried', 9),
#  (u'changes', 9),
#  (u'prevents', 9),
#  (u'exported', 9),
#  (u'relieve', 9),
#  (u'Founded', 9),
#  (u'confused', 9),
#  (u'borrowing', 9),
#  (u'advance', 9),
#  (u'gathering', 9),
#  (u'stretched', 9),
#  (u'aiming', 9),
#  (u'organizing', 9),
#  (u'unsettled', 9),
#  (u'tackle', 9),
#  (u'sung', 9),
#  (u'enjoying', 9),
#  (u'threatens', 9),
#  (u'print', 9),
#  (u'declare', 9),
#  (u'express', 9),
#  (u'consume', 9),
#  (u'encountered', 9),
#  (u'shape', 9),
#  (u'streamlining', 9),
#  (u'prepares', 9),
#  (u'dogged', 9),
#  (u'train', 9),
#  (u'burdened', 9),
#  (u'racked', 9),
#  (u'insure', 9),
#  (u'misstated', 9),
#  (u'disciplined', 9),
#  (u'auction', 9),
#  (u'streamline', 9),
#  (u'brushed', 9),
#  (u'diversifying', 9),
#  (u'trust', 9),
#  (u'transformed', 9),
#  (u'judge', 9),
#  (u'speaks', 9),
#  (u'syndicated', 9),
#  (u'undervalued', 9),
#  (u'Stung', 9),
#  (u'float', 9),
#  (u'catching', 9),
#  (u'surviving', 9),
#  (u'guided', 9),
#  (u'poised', 9),
#  (u'disrupt', 9),
#  (u'discouraging', 9),
#  (u'executing', 9),
#  (u'markets', 9),
#  (u'examined', 9),
#  (u'traveled', 9),
#  (u'notify', 9),
#  (u'costing', 9),
#  (u'confirms', 9),
#  (u'flows', 9),
#  (u'drifted', 9),
#  (u'deployed', 9),
#  (u'generates', 9),
#  (u'buffeted', 9),
#  (u'depicted', 9),
#  (u'attend', 9),
#  (u'combat', 9),
#  (u'subscribe', 9),
#  (u'cross', 9),
#  (u'urges', 9),
#  (u'owe', 9),
#  (u'demonstrate', 9),
#  (u'hanging', 8),
#  (u'mired', 8),
#  (u'leaped', 8),
#  (u'attracts', 8),
#  (u'wind', 8),
#  (u'collapse', 8),
#  (u'idle', 8),
#  (u'employ', 8),
#  (u'deferring', 8),
#  (u'annualized', 8),
#  (u'raped', 8),
#  (u'benefiting', 8),
#  (u'stays', 8),
#  (u'materialized', 8),
#  (u'instructed', 8),
#  (u'altered', 8),
#  (u'equipped', 8),
#  (u'guarded', 8),
#  (u'worries', 8),
#  (u'enjoys', 8),
#  (u'tracking', 8),
#  (u'accumulated', 8),
#  (u'rush', 8),
#  (u'accompanying', 8),
#  (u'prevailed', 8),
#  (u'experience', 8),
#  (u'recognizing', 8),
#  (u'Had', 8),
#  (u'bounce', 8),
#  (u'dating', 8),
#  (u'Look', 8),
#  (u'deserves', 8),
#  (u'manipulate', 8),
#  (u'refinancing', 8),
#  (u'faded', 8),
#  (u'results', 8),
#  (u'defeat', 8),
#  (u'Leading', 8),
#  (u'practicing', 8),
#  (u'process', 8),
#  (u'outlined', 8),
#  (u'stimulate', 8),
#  (u'detailing', 8),
#  (u'behaved', 8),
#  (u'packed', 8),
#  (u'Get', 8),
#  (u'accelerating', 8),
#  (u'chooses', 8),
#  (u'wore', 8),
#  (u'devote', 8),
#  (u'sliding', 8),
#  (u'forces', 8),
#  (u'appealing', 8),
#  (u'bracing', 8),
#  (u'wooing', 8),
#  (u'outperformed', 8),
#  (u'cooled', 8),
#  (u'reset', 8),
#  (u'dedicated', 8),
#  (u'distorted', 8),
#  (u'notice', 8),
#  (u'Give', 8),
#  (u'floating', 8),
#  (u'touch', 8),
#  (u'trailed', 8),
#  (u'Adds', 8),
#  (u'tumbling', 8),
#  (u'intervene', 8),
#  (u'shifted', 8),
#  (u'woo', 8),
#  (u'threaten', 8),
#  (u'cleaning', 8),
#  (u'lasts', 8),
#  (u'drag', 8),
#  (u'stunned', 8),
#  (u'crossed', 8),
#  (u'attack', 8),
#  (u'lists', 8),
#  (u'grab', 8),
#  (u'spared', 8),
#  (u'publicized', 8),
#  (u'demonstrates', 8),
#  (u'pumped', 8),
#  (u'devise', 8),
#  (u'defer', 8),
#  (u'worsening', 8),
#  (u'restricting', 8),
#  (u'dismiss', 8),
#  (u'practiced', 8),
#  (u'ailing', 8),
#  (u'views', 8),
#  (u'outweigh', 8),
#  (u'worrying', 8),
#  (u'Noting', 8),
#  (u'promising', 8),
#  (u'assessing', 8),
#  (u'resembles', 8),
#  (u'titled', 8),
#  (u'peaked', 8),
#  (u'surrendered', 8),
#  (u'matters', 8),
#  (u'adjusting', 8),
#  (u'implied', 8),
#  (u'Assuming', 8),
#  (u'composed', 8),
#  (u'arranging', 8),
#  (u'billed', 8),
#  (u'grabbed', 8),
#  (u'phased', 8),
#  (u'commenting', 8),
#  (u'exhausted', 8),
#  (u'overshadowed', 8),
#  (u'dressed', 8),
#  (u'depress', 8),
#  (u'hang', 8),
#  (u'bail', 8),
#  (u'breaks', 8),
#  (u'disappeared', 8),
#  (u'constructed', 8),
#  (u'permitting', 8),
#  (u'crippled', 8),
#  (u'chaired', 8),
#  (u'qualified', 8),
#  (u'returns', 8),
#  (u'copy', 8),
#  (u'Operating', 8),
#  (u'slashing', 8),
#  (u'circulating', 8),
#  (u'minimize', 8),
#  (u'OFFERED', 8),
#  (u'applying', 8),
#  (u'prolonged', 8),
#  (u'protects', 8),
#  (u'arise', 8),
#  (u'capitalize', 8),
#  (u'weighs', 8),
#  (u'feed', 8),
#  (u'depleted', 8),
#  (u'confiscated', 8),
#  (u'relying', 8),
#  (u'oversee', 8),
#  (u'highlight', 8),
#  (u'dealt', 8),
#  (u'traveling', 8),
#  (u'inclined', 8),
#  (u'interrupted', 8),
#  (u'boosts', 8),
#  (u'ensuring', 8),
#  (u'appropriated', 8),
#  (u'ranks', 8),
#  (u'granting', 7),
#  (u'stabbed', 7),
#  (u'affiliated', 7),
#  (u'outlawed', 7),
#  (u'contemplated', 7),
#  (u'marched', 7),
#  (u'portrayed', 7),
#  (u'occurring', 7),
#  (u'misled', 7),
#  (u'imposes', 7),
#  (u'proves', 7),
#  (u'accomplished', 7),
#  (u'stress', 7),
#  (u'feature', 7),
#  (u'compelled', 7),
#  (u'repaired', 7),
#  (u'countered', 7),
#  (u'tightened', 7),
#  (u'rest', 7),
#  (u'discarded', 7),
#  (u'waived', 7),
#  (u'sang', 7),
#  (u'concluding', 7),
#  (u'disturbed', 7),
#  (u'plant', 7),
#  (u'broadcasting', 7),
#  (u'reminded', 7),
#  (u'reassured', 7),
#  (u'coping', 7),
#  (u'jeopardize', 7),
#  (u'cease', 7),
#  (u'averaging', 7),
#  (u'projects', 7),
#  (u'dictated', 7),
#  (u'line', 7),
#  (u'broaden', 7),
#  (u'illustrated', 7),
#  (u'flowing', 7),
#  (u'exacerbated', 7),
#  (u'courted', 7),
#  (u'accusing', 7),
#  (u'shaping', 7),
#  (u'rein', 7),
#  (u'delaying', 7),
#  (u'diversify', 7),
#  (u'tossed', 7),
#  (u'searched', 7),
#  (u'smoke', 7),
#  (u'refusing', 7),
#  (u'suing', 7),
#  (u'triggering', 7),
#  (u'classified', 7),
#  (u'incorporated', 7),
#  (u'implicated', 7),
#  (u'seated', 7),
#  (u'See', 7),
#  (u'quieted', 7),
#  (u'yielded', 7),
#  (u'plummeting', 7),
#  (u'tainted', 7),
#  (u'prescribed', 7),
#  (u'quotes', 7),
#  (u'scored', 7),
#  (u'Died', 7),
#  (u'striking', 7),
#  (u'ring', 7),
#  (u'upgrade', 7),
#  (u'justifies', 7),
#  (u'Depending', 7),
#  (u'suspected', 7),
#  (u'reap', 7),
#  (u'powered', 7),
#  (u'administered', 7),
#  (u'flattened', 7),
#  (u'punish', 7),
#  (u'amount', 7),
#  (u'trained', 7),
#  (u'trapped', 7),
#  (u'approves', 7),
#  (u'hobbled', 7),
#  (u'distinguish', 7),
#  (u'guide', 7),
#  (u'exercising', 7),
#  (u'lacking', 7),
#  (u'envisioned', 7),
#  (u'dashed', 7),
#  (u'focuses', 7),
#  (u'stage', 7),
#  (u'hesitate', 7),
#  (u'crossing', 7),
#  (u'prevailing', 7),
#  (u'undo', 7),
#  (u'crumbling', 7),
#  (u'processes', 7),
#  (u'limits', 7),
#  (u'sagged', 7),
#  (u'Have', 7),
#  (u'kick', 7),
#  (u'divest', 7),
#  (u'recruited', 7),
#  (u'projecting', 7),
#  (u'Includes', 7),
#  (u'calm', 7),
#  (u'recruiting', 7),
#  (u'enables', 7),
#  (u'attempts', 7),
#  (u'resisting', 7),
#  (u'jailed', 7),
#  (u'loaded', 7),
#  (u'Including', 7),
#  (u'strengthening', 7),
#  (u'answered', 7),
#  (u'refuses', 7),
#  (u'recoup', 7),
#  (u'rattled', 7),
#  (u'pumping', 7),
#  (u'upgrading', 7),
#  (u'shocked', 7),
#  (u'switching', 7),
#  (u'measuring', 7),
#  (u'importing', 7),
#  (u'talks', 7),
#  (u'stretching', 7),
#  (u'stir', 7),
#  (u'swamped', 7),
#  (u'swelling', 7),
#  (u'depended', 7),
#  (u'nonrecurring', 7),
#  (u'tender', 7),
#  (u'ravaged', 7),
#  (u'solicited', 7),
#  (u'ai', 7),
#  (u'mirror', 7),
#  (u'affects', 7),
#  (u'remembered', 7),
#  (u'infected', 7),
#  (u'cure', 7),
#  (u'cater', 7),
#  (u'portraying', 7),
#  (u'accuse', 7),
#  (u'industrialized', 7),
#  (u'reserved', 7),
#  (u'preclude', 7),
#  (u'thwart', 7),
#  (u'deprived', 7),
#  (u'facilitate', 7),
#  (u'tightening', 7),
#  (u'equal', 7),
#  (u'assure', 7),
#  (u'copied', 7),
#  (u'disappears', 7),
#  (u'arising', 7),
#  (u'displaced', 7),
#  (u'masked', 7),
#  (u'muddied', 7),
#  (u'touted', 7),
#  (u'shrank', 7),
#  (u'direct', 7),
#  (u'worsen', 7),
#  (u'shoot', 7),
#  (u'loosen', 7),
#  (u'celebrating', 7),
#  (u'free', 7),
#  (u'incur', 7),
#  (u'flow', 7),
#  (u'specialize', 7),
#  (u'renamed', 7),
#  (u'proceeding', 7),
#  (u'subsidize', 7),
#  (u'liquidate', 7),
#  (u'contemplating', 7),
#  (u'denounced', 7),
#  (u'eroding', 7),
#  (u'supplying', 7),
#  (u'harmed', 7),
#  (u'whipsawed', 7),
#  (u'inform', 7),
#  (u'narrows', 7),
#  (u'violates', 7),
#  (u'detect', 7),
#  (u'reimburse', 7),
#  (u'cash', 7),
#  (u'arose', 7),
#  (u'dying', 7),
#  (u'Made', 7),
#  (u'confined', 7),
#  (u'preceding', 7),
#  (u'freed', 7),
#  (u'Remember', 7),
#  (u'regard', 7),
#  (u'separate', 7),
#  (u'booked', 7),
#  (u'racing', 7),
#  (u'sticking', 7),
#  (u'conspiring', 7),
#  (u'widens', 7),
#  (u'disagreed', 7),
#  (u'plummet', 7),
#  (u'intervened', 7),
#  (u'flies', 7),
#  (u'Advancing', 7),
#  (u'rid', 7),
#  (u'stimulated', 7),
#  (u'Reflecting', 7),
#  (u'encourages', 7),
#  (u'capitalized', 7),
#  (u'underscored', 7),
#  (u'sort', 7),
#  (u'restrain', 7),
#  (u'flee', 7),
#  (u'approaching', 7),
#  (u'tacked', 7),
#  (u'Citing', 7),
#  (u'stymied', 7),
#  (u'spurring', 7),
#  (u'married', 7),
#  (u'weighing', 7),
#  (u'retailing', 7),
#  (u'sinking', 6),
#  (u'dreamed', 6),
#  (u'rewarded', 6),
#  (u'fix', 6),
#  (u'competes', 6),
#  (u'cooling', 6),
#  (u'defaulted', 6),
#  (u'endure', 6),
#  (u'committing', 6),
#  (u'looming', 6),
#  (u'leasing', 6),
#  (u'sacrificing', 6),
#  (u'heating', 6),
#  (u'trusted', 6),
#  (u'echoed', 6),
#  (u'Think', 6),
#  (u'forming', 6),
#  (u'disclosing', 6),
#  (u'suspending', 6),
#  (u'understanding', 6),
#  (u'reclaim', 6),
#  (u'spot', 6),
#  (u'Encouraged', 6),
#  (u'celebrate', 6),
#  (u'matches', 6),
#  (u'retrieve', 6),
#  (u'collapsing', 6),
#  (u'inserted', 6),
#  (u'intensifying', 6),
#  (u'pop', 6),
#  (u'restoring', 6),
#  (u'walks', 6),
#  (u'extract', 6),
#  (u'abolish', 6),
#  (u'mimic', 6),
#  (u'pulls', 6),
#  (u'installing', 6),
#  (u'evolved', 6),
#  (u'sense', 6),
#  (u'condemn', 6),
#  (u'replies', 6),
#  (u'misses', 6),
#  (u'erupted', 6),
#  (u'defends', 6),
#  (u'remembers', 6),
#  (u'rejecting', 6),
#  (u'sink', 6),
#  (u'picks', 6),
#  (u'signals', 6),
#  (u'prosecuted', 6),
#  (u'assisting', 6),
#  (u'land', 6),
#  (u'reasoned', 6),
#  (u'wipe', 6),
#  (u'drill', 6),
#  (u'destroying', 6),
#  (u'await', 6),
#  (u'Aided', 6),
#  (u'steer', 6),
#  (u'taxed', 6),
#  (u'drum', 6),
#  (u'invites', 6),
#  (u'recurring', 6),
#  (u'sits', 6),
#  (u'concealing', 6),
#  (u'softening', 6),
#  (u'repassed', 6),
#  (u'transport', 6),
#  (u'revise', 6),
#  (u'restricts', 6),
#  (u'bearing', 6),
#  (u'repeal', 6),
#  (u'Faced', 6),
#  (u'clarify', 6),
#  (u'lag', 6),
#  (u'feeds', 6),
#  (u'hedging', 6),
#  (u'diversified', 6),
#  (u'wasted', 6),
#  (u'assessed', 6),
#  (u'haunted', 6),
#  (u'observes', 6),
#  (u'air', 6),
#  (u'aim', 6),
#  (u'applies', 6),
#  (u'Compiled', 6),
#  (u'expelled', 6),
#  (u'Try', 6),
#  (u'provoked', 6),
#  (u'computing', 6),
#  (u'mulling', 6),
#  (u'terminate', 6),
#  (u'burn', 6),
#  (u'posing', 6),
#  (u'sacrifice', 6),
#  (u'offend', 6),
#  (u'rebuilding', 6),
#  (u'eliminates', 6),
#  (u'suspects', 6),
#  (u'donating', 6),
#  (u'alleviate', 6),
#  (u'stung', 6),
#  (u'freeing', 6),
#  (u'gambling', 6),
#  (u'nearing', 6),
#  (u'modify', 6),
#  (u'answers', 6),
#  (u'colored', 6),
#  (u'criticize', 6),
#  (u'dulled', 6),
#  (u'obligated', 6),
#  (u'dominates', 6),
#  (u'hindered', 6),
#  (u'numbered', 6),
#  (u'bowed', 6),
#  (u'eaten', 6),
#  (u'stalked', 6),
#  (u'liked', 6),
#  (u'endanger', 6),
#  (u'reads', 6),
#  (u'clears', 6),
#  (u'appalled', 6),
#  (u'inviting', 6),
#  (u'placing', 6),
#  (u'Called', 6),
#  (u'forge', 6),
#  (u'calculating', 6),
#  (u'sounded', 6),
#  (u'excluded', 6),
#  (u'underscore', 6),
#  (u'dilute', 6),
#  (u'foresee', 6),
#  (u'rendered', 6),
#  (u'documented', 6),
#  (u'slide', 6),
#  (u'attach', 6),
#  (u'wrapped', 6),
#  (u'disgorge', 6),
#  (u'state', 6),
#  (u'surface', 6),
#  (u'Be', 6),
#  (u'lured', 6),
#  (u'extends', 6),
#  (u'crushed', 6),
#  (u'survey', 6),
#  (u'tempered', 6),
#  (u'recognizes', 6),
#  (u'blaming', 6),
#  (u'curbed', 6),
#  (u'calculate', 6),
#  (u'rescue', 6),
#  (u'aligned', 6),
#  (u'stressing', 6),
#  (u'persist', 6),
#  (u'afforded', 6),
#  (u'unleashed', 6),
#  (u'integrate', 6),
#  (u'confronted', 6),
# ...
#  (u'when-issued', 1),
#  (u'indemnify', 1),
#  (u'shrug', 1),
#  (u'highlighting', 1),
#  (u'Applying', 1),
#  (u'pollute', 1),
#  (u'Heating', 1),
#  (u'host', 1),
#  (u'distilling', 1),
#  (u'romancing', 1),
#  (u'evoke', 1),
#  (u'submits', 1),
#  (u'brands', 1),
#  (u'gleaned', 1),
#  (u'revolve', 1),
#  (u'aggravates', 1),
#  (u'clamored', 1),
#  (u'Legislating', 1),
#  (u'plague', 1),
#  (u'backfires', 1),
#  (u'penetrating', 1),
#  (u'gush', 1),
#  (u'overpurchase', 1),
#  (u'inhibited', 1),
#  (u'dresses', 1),
#  (u'conveys', 1),
#  (u'excite', 1),
#  (u'Diversify', 1),
#  (u'Sleep', 1),
#  (u'deregulated', 1),
#  (u'propsed', 1),
#  (u'Lean', 1),
#  (u'slogs', 1),
#  (u'GROWING', 1),
#  (u'Re-creating', 1),
#  (u'rendezvoused', 1),
#  (u'whipsaw', 1),
#  (u'placated', 1),
#  (u'Withhold', 1),
#  (u'jack', 1),
#  (u'reiterating', 1),
#  (u'Shook', 1),
#  (u'school', 1),
#  (u'postponing', 1),
#  (u'guiding', 1),
#  (u'enclosing', 1),
#  (u'parted', 1),
#  (u'Ruffled', 1),
#  (u'razed', 1),
#  (u'scrutinize', 1),
#  (u'Abandoning', 1),
#  (u'reacts', 1),
#  (u'democratized', 1),
#  (u'stared', 1),
#  (u'Labeling', 1),
#  (u'socialize', 1),
#  (u'overplanted', 1),
#  (u'whisked', 1),
#  (u'disclaims', 1),
#  (u'depreciated', 1),
#  (u'prints', 1),
#  (u'ridiculed', 1),
#  (u'grumbled', 1),
#  (u'ridicules', 1),
#  (u'punching', 1),
#  (u'perpetuates', 1),
#  (u'swings', 1),
#  (u'lessening', 1),
#  (u'mediate', 1),
#  (u'sobered', 1),
#  (u'fainting', 1),
#  (u'breathe', 1),
#  (u'ferrying', 1),
#  (u'acceded', 1),
#  (u'phone', 1),
#  (u'pinching', 1),
#  (u'Accrued', 1),
#  (u'outdated', 1),
#  (u'brandishing', 1),
#  (u'prearranged', 1),
#  (u'Traveling', 1),
#  (u'MAKING', 1),
#  (u'legislate', 1),
#  (u'aching', 1),
#  (u'predicated', 1),
#  (u'poked', 1),
#  (u'spout', 1),
#  (u'Japanese', 1),
#  (u'outshine', 1),
#  (u'digest', 1),
#  (u'swapped', 1),
#  (u'exhibits', 1),
#  (u'tilts', 1),
#  (u'decribed', 1),
#  (u'roost', 1),
#  (u'ripens', 1),
#  (u'Maintain', 1),
#  (u'ennumerated', 1),
#  (u'TALKS', 1),
#  (u'Transport', 1),
#  (u'tucking', 1),
#  (u'dodged', 1),
#  (u'hanged', 1),
#  (u'lugged', 1),
#  (u'pounce', 1),
#  (u'splashed', 1),
#  (u'slivered', 1),
#  (u'associate', 1),
#  (u'immigrated', 1),
#  (u'gushes', 1),
#  (u'blackmailing', 1),
#  (u'paves', 1),
#  (u'aspire', 1),
#  (u'inspectors', 1),
#  (u'Renewed', 1),
#  (u'Working', 1),
#  (u'researches', 1),
#  (u'awoke', 1),
#  (u'Shaving', 1),
#  (u'sidelining', 1),
#  (u'acidified', 1),
#  (u'downsize', 1),
#  (u'airlifting', 1),
#  (u'Benefit', 1),
#  (u'Amending', 1),
#  (u'classed', 1),
#  (u'pre-tested', 1),
#  (u'bridge', 1),
#  (u'fashion', 1),
#  (u'rat', 1),
#  (u'appreciating', 1),
#  (u'slithering', 1),
#  (u'upholding', 1),
#  (u'isolates', 1),
#  (u'harped', 1),
#  (u'Absent', 1),
#  (u'innovate', 1),
#  (u'interjects', 1),
#  (u'Biking', 1),
#  (u'parting', 1),
#  (u'Promises', 1),
#  (u'unroll', 1),
#  (u'entertaining', 1),
#  (u'flog', 1),
#  (u'yank', 1),
#  (u'pardoned', 1),
#  (u'mishandling', 1),
#  (u'labels', 1),
#  (u'aspires', 1),
#  (u'pops', 1),
#  (u'Pickin', 1),
#  (u'delays', 1),
#  (u'lodge', 1),
#  (u'Surrender', 1),
#  (u'Turns', 1),
#  (u'squeaking', 1),
#  (u'intersperses', 1),
#  (u'thumbs', 1),
#  (u'thrashing', 1),
#  (u'presuming', 1),
#  (u'thwarting', 1),
#  (u'sharpens', 1),
#  (u'discovers', 1),
#  (u'prune', 1),
#  (u'herding', 1),
#  (u'phoning', 1),
#  (u'fault', 1),
#  (u'spurs', 1),
#  (u'GIVE', 1),
#  (u'subscribing', 1),
#  (u'pedaling', 1),
#  (u'subverts', 1),
#  (u'lorded', 1),
#  (u'patronizing', 1),
#  (u'parched', 1),
#  (u'Follow', 1),
#  (u'precede', 1),
#  (u'Owning', 1),
#  (u'brewed', 1),
#  (u'circumventing', 1),
#  (u'heeded', 1),
#  (u'twiddling', 1),
#  (u'constricting', 1),
#  (u'Ashland', 1),
#  (u'mentioning', 1),
#  (u'Managed', 1),
#  (u'alarms', 1),
#  (u'arousing', 1),
#  (u'feuded', 1),
#  (u'modulate', 1),
#  (u'enlighten', 1),
#  (u'sprinkled', 1),
#  (u'interprets', 1),
#  (u'grouses', 1),
#  (u'Discounted', 1),
#  (u'sidestepped', 1),
#  (u'spanned', 1),
#  (u'reapportion', 1),
#  (u'burns', 1),
#  (u'spawns', 1),
#  (u'melting', 1),
#  (u'refocusing', 1),
#  (u'outgrew', 1),
#  (u'Experienced', 1),
#  (u'clash', 1),
#  (u'embodies', 1),
#  (u'kayoed', 1),
#  (u'arbitrates', 1),
#  (u'shivering', 1),
#  (u'attacks', 1),
#  (u'twitch', 1),
#  (u'Provided', 1),
#  (u'Touches', 1),
#  (u'froze', 1),
#  (u'puzzle', 1),
#  (u'Survive', 1),
#  (u'emigrate', 1),
#  (u'minted', 1),
#  (u'dispatching', 1),
#  (u'scamper', 1),
#  (u'Competing', 1),
#  (u'steers', 1),
#  (u'pervade', 1),
#  (u'heal', 1),
#  (u'refashioning', 1),
#  (u'pricked', 1),
#  (u'lashed', 1),
#  (u'bargain', 1),
#  (u'Fires', 1),
#  (u'latch', 1),
#  (u'adorn', 1),
#  (u'Towering', 1),
#  (u'quashing', 1),
#  (u'stoking', 1),
#  (u'tip', 1),
#  (u'vanishes', 1),
#  (u'ORGANIZED', 1),
#  (u'implant', 1),
#  (u'congratulate', 1),
#  (u'impounded', 1),
#  (u'propelling', 1),
#  (u'hashing', 1),
#  (u'apologizing', 1),
#  (u'obviate', 1),
#  (u'functioned', 1),
#  (u'Gets', 1),
#  (u'row', 1),
#  (u'Mourning', 1),
#  (u'pleases', 1),
#  (u'furrows', 1),
#  (u'advantage', 1),
#  (u'cook', 1),
#  (u'Spotted', 1),
#  (u'sighed', 1),
#  (u'posts', 1),
#  (u'culminating', 1),
#  (u'couched', 1),
#  (u'invades', 1),
#  (u'lavishing', 1),
#  (u'comforting', 1),
#  (u'toughen', 1),
#  (u'guards', 1),
#  (u'Hurts', 1),
#  (u'channeled', 1),
#  (u'creamed', 1),
#  (u'water', 1),
#  (u'tallying', 1),
#  (u'chastened', 1),
#  (u'snubbed', 1),
#  (u'sharpening', 1),
#  (u'descended', 1),
#  (u'Floating', 1),
#  (u'Seek', 1),
#  (u'Visiting', 1),
#  (u'sports', 1),
#  (u'parties', 1),
#  (u'deplores', 1),
#  (u'teased', 1),
#  (u'dislikes', 1),
#  (u'demonized', 1),
#  (u'Calling', 1),
#  (u'Push', 1),
#  (u'cases', 1),
#  (u'inhabit', 1),
#  (u'photocopying', 1),
#  (u'quacks', 1),
#  (u'sprouting', 1),
#  (u'lucked', 1),
#  (u'begs', 1),
#  (u'levy', 1),
#  (u'scoff', 1),
#  (u'curing', 1),
#  (u'COMPARE', 1),
#  (u'amuse', 1),
#  (u'eyeballing', 1),
#  (u'branched', 1),
#  (u'Misunderstanding', 1),
#  (u'Moving', 1),
#  (u'qualifies', 1),
#  (u'Linger', 1),
#  (u'appraised', 1),
#  (u'warranted', 1),
#  (u'boozing', 1),
#  (u'Triggering', 1),
#  (u'clutch', 1),
#  (u'synchronize', 1),
#  (u'dabs', 1),
#  (u'rethinking', 1),
#  (u'Leveraged', 1),
#  (u'Distributing', 1),
#  (u'lambasted', 1),
#  (u'Save', 1),
#  (u'concur', 1),
#  (u'factors', 1),
#  (u'Leaping', 1),
#  (u'cancels', 1),
#  (u'abounding', 1),
#  (u'Throw', 1),
#  (u'maneuver', 1),
#  (u'Record', 1),
#  (u'dig', 1),
#  (u'intones', 1),
#  (u're-emphasize', 1),
#  (u'flare', 1),
#  (u'deceived', 1),
#  (u'spiraled', 1),
#  (u'fetched', 1),
#  (u'accorded', 1),
#  (u'fetches', 1),
#  (u'simplified', 1),
#  (u'peddles', 1),
#  (u'clanking', 1),
#  (u'haggle', 1),
#  (u'hum', 1),
#  (u'girded', 1),
#  (u'looting', 1),
#  (u'computes', 1),
#  (u'ooze', 1),
#  (u'froth', 1),
#  (u'denude', 1),
#  (u'exchanging', 1),
#  (u'batting', 1),
#  (u'foundered', 1),
#  (u'dining', 1),
#  (u'resembling', 1),
#  (u'boiling', 1),
#  (u'stormed', 1),
#  (u'precludes', 1),
#  (u'encasing', 1),
#  (u'pored', 1),
#  (u'denationalized', 1),
#  (u'trespass', 1),
#  (u'Opposed', 1),
#  (u'hack', 1),
#  (u'hustles', 1),
#  (u'Continuing', 1),
#  (u'furthering', 1),
#  (u'partake', 1),
#  (u'crimp', 1),
#  (u'mapped', 1),
#  (u'signs', 1),
#  (u'emote', 1),
#  (u'parking', 1),
#  (u'squandering', 1),
#  (u'braved', 1),
#  (u'indexed', 1),
#  (u'invokes', 1),
#  (u'U.S.', 1),
#  (u'Punching', 1),
#  (u'floundering', 1),
#  (u'Replied', 1),
#  (u'co-edits', 1),
#  (u'CLEARS', 1),
#  (u'deported', 1),
#  (u'pot', 1),
#  (u'hunched', 1),
#  (u'initialing', 1),
#  (u'endeavor', 1),
#  (u'poll', 1),
#  (u'subscribed', 1),
#  (u'Slated', 1),
#  (u'subscribes', 1),
#  (u'bequeathed', 1),
#  (u'deposited', 1),
#  (u'Laboring', 1),
#  (u'mocking', 1),
#  (u'implores', 1),
#  (u'WAS', 1),
#  (u'Divide', 1),
#  (u'rhymes', 1),
#  (u'lumped', 1),
#  (u'rhymed', 1),
#  (u'hunts', 1),
#  (u'Open', 1),
#  (u'interconnected', 1),
#  (u'telephone', 1),
#  (u'snaking', 1),
#  (u'pre-try', 1),
#  (u'dithering', 1),
#  (u'minting', 1),
#  (u'chuckling', 1),
#  (u'shifts', 1),
#  (u'fended', 1),
#  (u'TRIMMING', 1),
#  (u'barges', 1),
#  (u'excavated', 1),
#  (u'prospered', 1),
#  (u'Dream', 1),
#  (u'Bucking', 1),
#  (u'model', 1),
#  (u'loosening', 1),
#  (u'except', 1),
#  (u'discerns', 1),
#  (u'Change', 1),
#  (u'impound', 1),
#  (u'styled', 1),
#  (u'championing', 1),
#  (u'tower', 1),
#  (u'burdens', 1),
#  (u'picture', 1),
#  (u'overheated', 1),
#  (u'Located', 1),
#  (u'snatched', 1),
#  (u'Listen', 1),
#  (u'Knowing', 1),
#  (u'resonate', 1),
#  (u'calmed', 1),
#  (u'trivialize', 1),
#  (u'decelerated', 1),
#  (u'cursed', 1),
#  (u'Inject', 1),
#  (u'quiz', 1),
#  (u'sloshing', 1),
#  (u'DELAYS', 1),
#  (u'equates', 1),
#  (u'equated', 1),
#  (u'illuminates', 1),
#  (u'demilitarize', 1),
#  (u'tiptoe', 1),
#  (u'Setting', 1),
#  (u'frighten', 1),
#  (u'cringed', 1),
#  (u'aces', 1),
#  (u'encompass', 1),
#  (u'rubbed', 1),
#  (u'Hired', 1),
#  (u'proliferate', 1),
#  (u'winking', 1),
#  (u'Deafening', 1),
#  (u'lambastes', 1),
#  (u'exhausting', 1),
#  (u'dish', 1),
#  (u'Jutting', 1),
#  (u'diluting', 1),
#  (u'vitiate', 1),
#  (u'uptick', 1),
#  (u'ticked', 1),
#  (u'margined', 1),
#  (u'understand\\/adopt', 1),
#  (u'readied', 1),
#  (u'clinched', 1),
#  (u'cascading', 1),
#  (u'proscribes', 1),
#  (u'renouncing', 1),
#  (u'translating', 1),
#  (u'belied', 1),
#  (u'discern', 1),
#  (u'raked', 1),
#  (u'combating', 1),
#  (u'retraining', 1),
#  (u'Shorn', 1),
#  (u'observing', 1),
#  (u'pulverizing', 1),
#  (u'tramping', 1),
#  (u'exited', 1),
#  (u'bodes', 1),
#  (u'still-raging', 1),
#  (u'reaping', 1),
#  (u'refitting', 1),
#  (u'faint', 1),
#  (u'Lives', 1),
#  (u'demeaned', 1),
#  (u'pausing', 1),
#  (u'flay', 1),
#  (u'hissed', 1),
#  (u'Turned', 1),
#  (u'debated', 1),
#  (u'wrestles', 1),
#  (u'co-host', 1),
#  (u'conspire', 1),
#  (u'designate', 1),
#  (u'cleansing', 1),
#  (u'abdicate', 1),
#  (u'emulate', 1),
#  (u'dissolving', 1),
#  (u'stash', 1),
#  (u'shorn', 1),
#  (u'Armed', 1),
#  (u'gauges', 1),
#  (u'disabled', 1),
#  (u'underwhelmed', 1),
#  (u'reconnect', 1),
#  (u'forgiving', 1),
#  (u'unleashing', 1),
#  (u'glide', 1),
#  (u'stonewalled', 1),
#  (u'jogs', 1),
#  (u'waged', 1),
#  (u'panning', 1),
#  (u'belittle', 1),
#  (u'clouds', 1),
#  (u'hunted', 1),
#  (u'SURGED', 1),
#  (u'overused', 1),
#  (u'characterizes', 1),
#  (u'residing', 1),
#  (u'rerouted', 1),
#  (u'weight', 1),
#  (u'inflates', 1),
#  (u'pirated', 1),
#  (u'Reading', 1),
#  (u'frittering', 1),
#  (u'imploring', 1),
#  (u'adhere', 1),
#  (u'compounding', 1),
#  (u'induced', 1),
#  (u'hailing', 1),
#  (u'combed', 1),
#  (u'outsells', 1),
#  (u'outstripping', 1),
#  (u'stampede', 1),
#  (u'enlarged', 1),
#  (u'overrode', 1),
#  (u'moan', 1),
#  (u'finances', 1),
#  (u'option', 1),
#  (u'convinces', 1),
#  (u'Wrote', 1),
#  (u'nagging', 1),
#  (u'stall', 1),
#  (u'cuff', 1),
#  (u'pillorying', 1),
#  (u'delves', 1),
#  (u'silence', 1),
#  (u'depletes', 1),
#  (u'exert', 1),
#  (u'upped', 1),
#  (u'delisted', 1),
#  (u'interferes', 1),
#  (u'MOVED', 1),
#  (u'conforming', 1),
#  (u'establshed', 1),
#  (u'MOVES', 1),
#  (u'interfered', 1),
#  (u'populate', 1),
#  (u'reunited', 1),
#  (u'diversifed', 1),
#  (u'dissolves', 1),
#  (u'coincides', 1),
#  (u'out-smart', 1),
#  (u'DIALING', 1),
#  (u'BE', 1),
#  (u'stoned', 1),
#  (u'grazed', 1),
#  (u'cataloging', 1),
#  (u'Wilfred', 1),
#  (u'tacking', 1),
#  (u'hopscotched', 1),
#  (u'whistle', 1),
#  (u'hid', 1),
#  (u'reprint', 1),
#  (u'compiles', 1),
#  (u'JOINS', 1),
#  (u'heaping', 1),
#  (u'engraved', 1),
#  (u'signify', 1),
#  (u'heaped', 1),
#  (u'arm', 1),
#  (u'spirited', 1),
#  (u'learns', 1),
#  (u'BEING', 1),
#  (u'nailed', 1),
#  (u'ENDED', 1),
#  (u'dismantling', 1),
#  (u'franchises', 1),
#  (u'franchise', 1),
#  (u'Cementing', 1),
#  (u'accomodate', 1),
#  (u'reside', 1),
#  (u'previewing', 1),
#  (u'flied', 1),
#  (u'rave', 1),
#  (u'roaring', 1),
#  (u'canceling', 1),
#  (u'Projected', 1),
#  (u'cinch', 1),
#  (u'Sees', 1),
#  (u'stagewhispers', 1),
#  (u'balloons', 1),
#  (u'pampers', 1),
#  (u'SWUNG', 1),
#  (u'shortened', 1),
#  (u'canvassed', 1),
#  (u'enriching', 1),
#  (u'rim', 1),
#  (u'SHUN', 1),
#  (u'openended', 1),
#  (u'chauffeur', 1),
#  (u'flamed', 1),
#  (u'reasserts', 1),
#  (u'disenchanted', 1),
#  (u'destabilizing', 1),
#  (u'cheer', 1),
#  (u'mellowed', 1),
#  (u'Seems', 1),
#  (u'exonerating', 1),
#  (u'questions', 1),
#  (u'retaliating', 1),
#  (u'vetoing', 1),
#  (u'Aim', 1),
#  (u'entangled', 1),
#  (u'Revising', 1),
#  (u'rotate', 1),
#  (u'flabbergasted', 1),
#  (u'stagnating', 1),
#  (u'disinclined', 1),
#  (u'eluding', 1),
#  (u'vacate', 1),
#  (u'retry', 1),
#  (u'ticking', 1),
#  (u'Rejoins', 1),
#  (u'fragments', 1),
#  (u'contrasting', 1),
#  (u'beleaguered', 1),
#  (u'pinging', 1),
#  (u'tinker', 1),
#  (u'unhusked', 1),
#  (u'disassociate', 1),
#  (u'seeped', 1),
#  (u'fleets', 1),
#  (u'stitched', 1),
#  (u'acquiesce', 1),
#  (u'long', 1),
#  (u'impresses', 1),
#  (u'tutored', 1),
#  (u'succumbed', 1),
#  (u'interceded', 1),
#  (u'crank', 1),
#  (u'astounds', 1),
#  (u'stalking', 1),
#  (u'co-managing', 1),
#  (u'fried', 1),
#  (u'allayed', 1),
#  (u'sublet', 1),
#  (u'scrutinized', 1),
#  (u'grouped', 1),
#  (u'muddled', 1),
#  (u'inflame', 1),
#  (u'relaunch', 1),
#  (u'sapping', 1),
#  (u'NOTE', 1),
#  (u'steaming', 1),
#  (u'Foiled', 1),
#  (u'Peeking', 1),
#  (u'emoted', 1),
#  (u'sniped', 1),
#  (u'peering', 1),
#  (u'commissions', 1),
#  (u'melding', 1),
#  (u'spook', 1),
#  (u'bounding', 1),
#  (u'Kissing', 1),
#  (u'redistribute', 1),
#  (u'gripping', 1),
#  (u'flaunts', 1),
#  (u'manipulating', 1),
#  (u'appeased', 1),
#  (u'equipping', 1),
#  (u'Formed', 1),
#  (u'radar-eluding', 1),
#  (u'outlasted', 1),
#  (u'Link', 1),
#  (u'Clad', 1),
#  (u'tarred', 1),
#  (u'gloat', 1),
#  (u'incriminating', 1),
#  (u'spy', 1),
#  (u'shoved', 1),
#  (u'offends', 1),
#  (u'duck', 1),
#  (u'shoves', 1),
#  (u'weeping', 1),
#  (u'sanitize', 1),
#  (u'Land', 1),
#  (u'capitulated', 1),
#  (u'posturing', 1),
#  (u'nixed', 1),
#  (u'accrues', 1),
#  (u'dusted', 1),
#  (u'lumber', 1),
#  (u'stabilizes', 1),
#  (u'purports', 1),
#  (u'spying', 1),
#  (u'flaring', 1),
#  (u'dripping', 1),
#  (u'tag', 1),
#  (u'memorize', 1),
#  (u'tamper', 1),
#  (u'patronize', 1),
#  (u'Concocts', 1),
#  (u'fidgeting', 1),
#  (u'segmenting', 1),
#  (u'immersed', 1),
#  (u'detests', 1),
#  (u'abuse', 1),
#  (u'Reserved', 1),
#  (u'SIGNAL', 1),
#  (u'improvised', 1),
#  (u'crawling', 1),
#  (u'rusted', 1),
#  (u'strove', 1),
#  (u'Suffice', 1),
#  (u'campaigned', 1),
#  (u'indexing', 1),
#  (u'mollified', 1),
#  (u'edit', 1),
#  (u'Slowing', 1),
#  (u'Restrict', 1),
#  (u'Eliminating', 1),
#  (u'bills', 1),
#  (u'finalizing', 1),
#  (u'testifying', 1),
#  (u'indulges', 1),
#  (u'Borrowed', 1),
#  (u'respects', 1),
#  (u'clinching', 1),
#  (u'frolicked', 1),
#  (u'sufficed', 1),
#  (u'plaguing', 1),
#  (u'impart', 1),
#  (u'WON', 1),
#  (u'Gone', 1),
#  (u'segregated', 1),
#  (u'informs', 1),
#  (u'substantiate', 1),
#  (u'Americanized', 1),
#  (u'regaining', 1),
#  (u'castling', 1),
#  (u'undid', 1),
#  (u'wimp', 1),
#  (u'Increased', 1),
#  (u'misunderstood', 1),
#  (u'fumpered', 1),
#  (u'Swiveling', 1),
#  (u'slides', 1),
#  (u'resurrects', 1),
#  (u'summoning', 1),
#  (u'underpriced', 1),
#  (u'elongate', 1),
#  (u'clip', 1),
#  (u'outstrip', 1),
#  (u'Compounding', 1),
#  (u'marginalizing', 1),
#  (u'oozing', 1),
#  (u'rearranges', 1),
#  (u'Kiss', 1),
#  (u'siphon', 1),
#  (u'cracking', 1),
#  (u'refreshing', 1),
#  (u'GET', 1),
#  (u'ensued', 1),
#  (u'bulging', 1),
#  (u'subtracting', 1),
#  (u'studded', 1),
#  (u'Measured', 1),
#  (u'outsell', 1),
#  (u'prosecute', 1),
#  (u'skimp', 1),
#  (u'Considered', 1),
#  (u'Persuading', 1),
#  (u'coordinating', 1),
#  (u'retools', 1),
#  (u'queried', 1),
#  (u'compliment', 1),
#  (u'queries', 1),
#  (u'Spooked', 1),
#  (u'buzzes', 1),
#  (u'ebb', 1),
#  (u'expel', 1),
#  (u'diverge', 1),
#  (u'Govern', 1),
#  (u'torpedo', 1),
#  (u'reexamining', 1),
#  (u'spoil', 1),
#  (u'withstanding', 1),
#  (u'Satisfying', 1),
#  (u'wall', 1),
#  (u'fledging', 1),
#  (u'DELIGHT', 1),
#  (u'charts', 1),
#  (u'short-circuited', 1),
#  (u'validating', 1),
#  (u'sidesteps', 1),
#  (u'bewildering', 1),
#  (u'underutilized', 1),
#  (u'rekindling', 1),
#  (u'align', 1),
#  (u'will', 1),
#  (u'rename', 1),
#  (u'disapprove', 1),
#  (u'frying', 1),
#  (u'brandished', 1),
#  (u'subcontract', 1),
#  (u'hammering', 1),
#  (u'banded', 1),
#  (u'sensing', 1),
#  (u'replenish', 1),
#  (u'cries', 1),
#  (u'reincorporated', 1),
#  (u'fishing', 1),
#  (u'console', 1),
#  (u'stowed', 1),
#  (u'captivating', 1),
#  (u'term', 1),
#  (u'countervailing', 1),
#  (u'Dealing', 1),
#  (u'growth', 1),
#  (u'holler', 1),
#  (u'neglecting', 1),
#  (u'scares', 1),
#  (u'disrupting', 1),
#  (u'obey', 1),
#  (u'metabolized', 1),
#  (u'devouring', 1),
#  (u'brush', 1),
#  (u'fawning', 1),
#  (u'blanketed', 1),
#  (u'preapproved', 1),
#  (u'resists', 1),
#  (u'automates', 1),
#  (u'alienated', 1),
#  (u'funds', 1),
#  (u'approximates', 1),
#  (u'recede', 1),
#  (u'Writes', 1),
#  (u'bombarding', 1),
#  (u'kneaded', 1),
#  (u'SEPARATED', 1),
#  (u'roars', 1),
#  (u'Improving', 1),
#  (u'shredded', 1),
#  (u'frustrate', 1),
#  (u'fleeced', 1),
#  (u'shadowing', 1),
#  (u'Coach', 1),
#  (u'Surviving', 1),
#  (u'infuriated', 1),
#  (u'alienates', 1),
#  (u'fending', 1)]

# %%
freqDict[u'think'] + freqDict[u'thought'] + freqDict[u'thinking'] + freqDict[u'thinks']
# Out:
# 594

# %%
2500 + freqDict[u'saying']
# Out:
# 2641

# %% [markdown]
# ## Problem 3
#
# Build a subclass of the `SearchTree` class in `runTregex.py` that contains a method `adjacent(self, elt)`, which checks whether adjacent to `self` is a treelet bearing the `elt` as node label (for non-terminals) or value (in the case of leaves).

# %% [markdown]
# <center><h2>Annotation Exercises<h2></center>

# %% [markdown]
# ## Problem 4
#
# Using `nltk.download` please download the movie reviews corpus. For the first five neg (cv000_29416.txt to cv005_29357.txt) and first five pos reviews (cv000_29590.txt to cv005_29443.txt), please go through and mark up the following. To do this, you will be wrapping bits of text in the tags below.
#
# 1. Actor names: Mark each actor in the film with `<A />`
# Please mark each actor every time they are mentioned and include as much of the name as is continguously mentioned at one time.
#
# 2. Character names: Mark each character in the film with  `<C />`
# Please mark each character every time they are mentioned and include as much of the name as is continguously mentioned at one time.
#
# 3. Movie Name `<M />`
# This is the name of the movie being reviewed.
#
# 4. Other movie names `<O />`
# Other movies are sometimes referenced in a review. Mark all instances.
#
# In addition, per sentence (i.e., line) please mark the overall purpose of the sentence with respect to the types below.
#
# 1. Plot description [p]
# The central purpose is to describe the structure of the movie's plot, not to comment on it.
#
# 2. Evaluation [e]
# The central purpose is to provide an opinion or evaluation. This does not have to be about the movie directly.
#
# 3. Ground for evaluation [g]
# This category indicates the reasons for an evaluation.
#
# 4. Other [o]
# None of the above
#
# In cases where a sentence has multiple types, choose the one that seems most central to the sentence. `Please see exampleAnnotation.txt`

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
# Hit Enter to continue:
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
#   [ ] langid.............. Language Id Corpus
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nps_chat............ NPS Chat
# Hit Enter to continue:
#   [ ] oanc_masc........... Open American National Corpus: Manually
#                            Annotated Sub-Corpus
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] ptb................. Penn Treebank
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] semcor.............. SemCor 3.0
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] state_union......... C-Span State of the Union Address Corpus
# Hit Enter to continue:
#   [ ] stopwords........... Stopwords Corpus
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] unicode_samples..... Unicode Samples
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
# Hit Enter to continue:
#   [ ] sample_grammars..... Sample Grammars
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] tagsets............. Help on Tagsets
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
#   [ ] hmm_treebank_pos_tagger Treebank Part of Speech Tagger (HMM)
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] punkt............... Punkt Tokenizer Models
#
# Collections:
#   [ ] all-corpora......... All the corpora
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier> movie_reviews
#     Downloading package 'movie_reviews' to /Users/ibersue/nltk_data...
#       Unzipping corpora/movie_reviews.zip.
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# ## Problem 5
#
# Now please come up with some distinction (2-5 labels) that you think might be interesting or important in the movie data. Construct a codebook, including examples for each category and a discussion of problem areas. Annotate the 10 movie reviews with your coding scheme.
