# %% [markdown]
# In the following series of problems, you will create a class that will load a text file from the data directory on the class site, and produce, based on that file and the CMU Pronouncing Dictionary, a phoneme *frequency table*.

# %% [markdown]
# ## Problem 1
#
# Your job in the first problem is simply to load the file, and tokenize it. The relevant files to choose are in the data/SampleTexts directory. There are two ways of saying where that is. There is the short or *relative* path, which is given from where this notebook is (homework/HW3). In such paths, to go up, one uses two periods. So, ".." means the parent of HW3, which is homework, and "../.." is the github repo root.
#
# Use relative paths to open one of the files in SampleTexts. Write another function that reads through the text, line by line, and tokenizes it. Since we are going for phonemes, you can ignore any tokens not in the CMU dictionary, including punctuation. Your tokenizer should examine the CMU dictionary and return a list of tokens, where each token is the CMU pronunciation for that word. If the word has multiple pronunciations, choose the first. If the word isn't in the dictionary, just ignore it.

# %%
import re #import regular expression characters to later use them
import json #import json file format
f = open("cmdict7a.json", "r")
dictionary = json.load(f) #assign the variable 'dictionary' to the imported file
f.close()

import os
os.chdir("/Users/ibersue/Documents/Computational Methods /144coursework/Homeworks/Homework 3")
os.getcwd()

path = "../SampleTexts/grimms"

def tokenizer(path):
    t = open(path, "r")
    wordslist = []
    for line in t:
        line = re.findall(r"[A-Za-z']+", line.lower()) #strip the punctuation with regular expression.
        for w in line:
            if w in dictionary:
                w = dictionary[w]
            else:
                w = ""
            for word in enumerate(w):
                word = w[0]
        wordslist.append(word)
    return wordslist

if __name__ == "__main__":
    grimmList = tokenizer(path)
    print grimmList
# Out:
# [[u'G', u'R', u'IH', u'M'], [u'G', u'R', u'IH', u'M'], [u'W', u'IH', u'DH'], [u'AO', u'R'], [u'IH', u'N', u'K', u'L', u'UW', u'D', u'AH', u'D'], [u'AO', u'R', u'G'], [u'AO', u'R', u'G'], [u'AO', u'R', u'G'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'G', u'R', u'IH', u'M'], [u'G', u'R', u'IH', u'M'], [u'M', u'EH', u'R', u'IY', u'AH', u'N'], [u'M', u'EH', u'R', u'IY', u'AH', u'N'], [u'D', u'IH', u'S', u'EH', u'M', u'B', u'ER'], [u'EY', u'P', u'R', u'AH', u'L'], [u'EY', u'P', u'R', u'AH', u'L'], [u'IH', u'NG', u'G', u'L', u'IH', u'SH'], [u'IH', u'NG', u'G', u'L', u'IH', u'SH'], [u'IH', u'NG', u'G', u'L', u'IH', u'SH'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'AH', u'N', u'D'], [u'AH', u'N', u'D'], [u'AH', u'N', u'D'], [u'AH', u'N', u'D'], [u'AH', u'N', u'D'], [u'AH', u'N', u'D'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'G', u'R', u'IH', u'M'], [u'G', u'R', u'IH', u'M'], [u'G', u'R', u'IH', u'M'], [u'G', u'R', u'IH', u'M'], [u'N', u'OW', u'T'], [u'N', u'OW', u'T'], [u'F', u'R', u'AH', u'M'], [u'B', u'AY'], [u'M', u'EH', u'R', u'IY', u'AH', u'N'], [u'M', u'EH', u'R', u'IY', u'AH', u'N'], [u'M', u'EH', u'R', u'IY', u'AH
', u'K', u'S'], [u'S', u'T', u'AO', u'R', u'IY'], [u'S', u'T', u'AO', u'R', u'IY'], [u'S', u'AE', u'L', u'AH', u'D'], [u'W', u'AA', u'Z'], [u'B', u'IH', u'R', u'D'], [u'HH', u'AA', u'N', u'S'], [u'S', u'K', u'IH', u'N'], [u'R', u'EH', u'D'], [u'R', u'EH', u'D'], [u'R', u'EH', u'D'], [u'R', u'EH', u'D'], [u'R', u'EH', u'D'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'T', u'EY', u'L', u'Z'], [u'B', u'ER', u'D'], [u'B', u'ER', u'D'], [u'T', u'R', u'IY'], [u'AH', u'B', u'AW', u'T'], [u'W', u'AH', u'N'], [u'DH', u'AH'], [u'HH', u'IH', u'Z'], [u'IH', u'N'], [u'W', u'AA', u'Z'], [u'M', u'AO', u'R', u'N', u'IH', u'NG'], [u'B',  ...

# %% [markdown]
# ## Problem 2
#
# Now, write another function that loops through the tokens and, for each word in turn, counts the number of times pairs of phonemes appear. Specifically, if a line was "how much wood could a wood chuck chuck if a woodchuck could chuck wood"
#
# with pronunciations
#
#
# [u'HH', u'AW'] [u'M', u'AH', u'CH'] [u'W', u'UH', u'D'] [u'K', u'UH', u'D'] [u'AH'] [u'W', u'UH', u'D'] [u'CH', u'AH', u'K'] [u'CH', u'AH', u'K'] [u'IH', u'F'] [u'AH'] [u'W', u'UH', u'D', u'CH', u'AH', u'K'] [u'K', u'UH', u'D'] [u'CH', u'AH', u'K'] [u'W', u'UH', u'D']
#
# we want a dict of dicts that ends up like this:
#
# {u'AH': {u'CH': 1, u'K': 4},
#  u'CH': {u'AH': 4},
#  u'D': {u'CH': 1},
#  u'HH': {u'AW': 1},
#  u'IH': {u'F': 1},
#  u'K': {u'UH': 2},
#  u'M': {u'AH': 1},
#  u'UH': {u'D': 6},
#  u'W': {u'UH': 4}}

# %%
def phonpair(phonList):
    from collections import Counter
    from itertools import chain, combinations
    pairs = Counter(chain.from_iterable(combinations(word, 2) for word in phonList ))
    print pairs

if __name__ == "__main__":
   phonpair(grimmList)
# Out:
# Counter({(u'AH', u'N'): 1124, (u'N', u'D'): 713, (u'AH', u'D'): 618, (u'DH', u'AH'): 572, (u'S', u'T'): 414, (u'IH', u'T'): 357, (u'EH', u'N'): 340, (u'IH', u'N'): 339, (u'IH', u'NG'): 324, (u'EH', u'D'): 300, (u'N', u'T'): 297, (u'T', u'AH'): 292, (u'S', u'D'): 291, (u'AO', u'R'): 291, (u'S', u'EH'): 288, (u'AH', u'T'): 287, (u'T', u'UW'): 281, (u'AH', u'L'): 279, (u'IH', u'L'): 262, (u'R', u'D'): 253, (u'R', u'AH'): 244, (u'L', u'D'): 229, (u'IH', u'Z'): 229, (u'HH', u'IH'): 228, (u'S', u'AH'): 226, (u'AE', u'T'): 220, (u'N', u'S'): 216, (u'R', u'IY'): 210, (u'AE', u'N'): 209, (u'EH', u'R'): 203, (u'HH
'): 97, (u'K', u'M'): 97, (u'B', u'L'): 97, (u'L', u'Z'): 96, (u'AE', u'Z'): 96, (u'AA', u'R'): 96, (u'HH', u'N'): 95, (u'B', u'N'): 94, (u'W', u'AY'): 93, (u'SH', u'IY'): 93, (u'M', u'T'): 93, (u'OW', u'N'): 93, (u'AE', u'AH'): 92, (u'AW', u'T'): 92, (u'R', u'AY'): 91, (u'N', u'N'): 91, (u'P', u'S'): 90, (u'P', u'IH'): 90, (u'K', u'S'): 90, (u'R', u'Z'): 89, (u'DH', u'AE'): 88, (u'S', u'R'): 88, (u'R', u'M'): 88, (u'F', u'L'): 88, (u'L', u'F'): 87, (u'AY', u'T'): 86, (u'M', u'S'): 85, (u'OW', u'L'): 84, (u'G', u'T'): 84, (u'AO', u'T'): 83, (u'HH', u'EH'): 83, (u'L', u'IH'): 83, (u'EH', u'ER'): 83, (u'G', u'AH'): 83, (u'P', u'L'): 83, (u'S', u'OW'): 82, (u'UW', u'AH'): 82, (u'AY', u'N'): 81, (u'M', u'ER'): 81, (u'B', u'ER'): 81, (u'F', u'AH'): 81, (u'G', u'D'): 80, (u'L', u'K'): 80, (u'W', u'EY'): 79, (u'R', u'L'): 79, (u'G', u'R'): 78, (u'DH', u'T'): 78, (u'AH', u'P'): 78, (u'T', u'EH'): 77, (u'S', u'S'): 77, (u'AH', u'B'): 76, (u'L', u'S'): 76, (u'D', u'Z'): 76, (u'F', u'ER'): 76, (u'AH', u'IY'): 75, (u'EH', u'S'): 75, (u'IH', u'F'): 75, (u'OW', u'D'): 73, (u'HH', u'AH'): 73, (u'S', u'K'): 72, (u'Y', u'AH'): 72, (u'K', u'AY'): 72, (u'D', u'ER'): 72, (u'N', u'Z'): 72, (u'R', u'K'): 72, (u'EH', u'V'): 72, (u'P', u'AA'): 71, (u'K', u'NG'): 71, (u'AE', u'ER'): 71, (u'G', u'L'): 71, (u'T', u' ...

# %% [markdown]
# ## Problem 3
#
# Write a function that is passed that dict of dicts and arranges all of it in a nice contingency table, like the one below.

# %% [raw]
#  AH  CH   D  HH  IH   K   M  UH   W
#       1               4             AH
#   4                                 CH
#       1                             D
#                                     HH
#                                     IH
#                               2     K
#   1                                 M
#           6                         UH
#                               4     W

# %% [markdown]
# ## Problem 4
#
# Now, write a class called `FrequencyTable` which takes a filename as an input and automatically reads the file, tokenizes it, and stores the frequency dictionary in self.frequencies.
#
# The class should have one special method `__str__`, which returns the contingency table above.

# %%
class FrequencyTable

# %% [markdown]
# ## Problem 5
#
# Extend your class to have the following special methods:
#
# 1. a `__len__` method, which returns the number of phonemes encountered across the file,
# 2. a `__cmp__` method, which compares two `FrequencyTable` instances by the number of phonemes that occur in each instance, and
# 3. a `__getitem__` method, which returns the subdict for a given first phoneme.
#
# For each of the 5 files in the SampleTexts directory, instantiate a class, and show the lengths and contingency tables from each except. Put them in a list and sort them in reverse.
